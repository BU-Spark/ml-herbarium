# %% [markdown]
# For our model the Swin transformer which is trained on the plant dataset provided by Harvard Herbarium, it was already in COCO format hence we just used those images and obtained predictions

# %%
import matplotlib.pyplot as plt

# %%
python tools/test.py 
configs/flowers/cascade_mask_rcnn_swin_small_patch4_window7_mstrain_480-800_giou_4conv1f_adamw_3x_coco_flower.py work_dirs/flowers_72_epochs/epoch_72.pth --eval bbox segm 
--show-dir /projectnb/ds549/students/kmn5409/tertiary_task/Swin/Swin-Transformer-Object-Detection/outputs/plants_72_epochs

# %%
from IPython.display import Image
Image('13752.jpg', width=720, height=1080)

# %% [markdown]
# Currently the model is only able to predict a single class. We are looking at different ways of improving the model such as data augmentation and potentially changing the hyperparameters when training.
#
# However because this is a vision transformer the model potentially may need more data than is available from this dataset.
