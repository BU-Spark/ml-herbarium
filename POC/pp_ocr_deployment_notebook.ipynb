# %% [markdown]
# Example to show how to use pp_ocr module, let's first visualize the origianl input image

# %%
# import all those helper function from utils. We will be using data loader to load all the images 
import pp_ocr_deployment
SRC_DIR = "/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/scraped-data/20220425-160006-matching/912082001.jpg"
save_dir = '/usr4/dl523/dong760/CS549_Herbarium_Project/ml-herbarium/PaddleOCR/output'
pp_ocr_deployment.display_img_with_img_path(img_path=SRC_DIR)
# Out:
# /share/pkg.7/python3/3.8.10/install/lib/python3.8/site-packages/skimage/filters/rank/generic.py:1: DeprecationWarning: invalid escape sequence \-
#   """
# 1.19.5

# %% [markdown]
# Now, let's use pp-ocr to perform the detection and recognition:

# %%
pp_ocr_deployment.display_OCR_result_with_img_path(img_path=SRC_DIR, save_dir=save_dir, display_result=True)
# Out:
# [[list([[389.0, 69.0], [412.0, 69.0], [412.0, 83.0], [389.0, 83.0]])
#   ('61', 0.8236742615699768)]
#  [list([[334.0, 90.0], [476.0, 87.0], [477.0, 110.0], [335.0, 113.0]])
#   ('H2004/0a232', 0.7764654755592346)]
#  [list([[389.0, 131.0], [429.0, 131.0], [429.0, 146.0], [389.0, 146.0]])
#   ('KEW', 0.9964563846588135)]
#  [list([[652.0, 1365.0], [895.0, 1362.0], [895.0, 1385.0], [652.0, 1388.0]])
#   ('HERB. HORT.BOT.REG. KEW.', 0.9611942172050476)]
#  [list([[692.0, 1425.0], [748.0, 1425.0], [748.0, 1446.0], [692.0, 1446.0]])
#   ('16324', 0.9963390231132507)]
#  [list([[690.0, 1444.0], [897.0, 1444.0], [897.0, 1473.0], [690.0, 1473.0]])
#   ('Solanum pinnatum Cav.', 0.9983992576599121)]
#  [list([[635.0, 1494.0], [704.0, 1494.0], [704.0, 1515.0], [635.0, 1515.0]])
#   ('Dupl. det.', 0.9415132403373718)]
#  [list([[713.0, 1492.0], [861.0, 1489.0], [861.0, 1512.0], [713.0, 1515.0]])
#   ('I. M. Johnston', 0.9958581328392029)]
# ...

# %% [markdown]
# If you prefer with the command line, you can run it with following command shown below, and the result will be saved into the directory that you provided

# %%
# !python pp_ocr_deployment.py -s /projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/scraped-data/20220425-160006-matching/912082001.jpg -r /usr4/dl523/dong760/CS549_Herbarium_Project/ml-herbarium/PaddleOCR/output
# Out:
# /share/pkg.7/python3/3.8.10/install/lib/python3.8/site-packages/skimage/filters/rank/generic.py:1: DeprecationWarning: invalid escape sequence \-
#   """
# 1.19.5
# args: Namespace(save_dir='/usr4/dl523/dong760/CS549_Herbarium_Project/ml-herbarium/PaddleOCR/output', src_path='/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/scraped-data/20220425-160006-matching/912082001.jpg')
# [[list([[389.0, 69.0], [412.0, 69.0], [412.0, 83.0], [389.0, 83.0]])
#   ('61', 0.8236742615699768)]
#  [list([[334.0, 90.0], [476.0, 87.0], [477.0, 110.0], [335.0, 113.0]])
#   ('H2004/0a232', 0.7764654755592346)]
#  [list([[389.0, 131.0], [429.0, 131.0], [429.0, 146.0], [389.0, 146.0]])
#   ('KEW', 0.9964563846588135)]
#  [list([[652.0, 1365.0], [895.0, 1362.0], [895.0, 1385.0], [652.0, 1388.0]])
#   ('HERB. HORT.BOT.REG. KEW.', 0.9611942172050476)]
#  [list([[692.0, 1425.0], [748.0, 1425.0], [748.0, 1446.0], [692.0, 1446.0]])
#   ('16324', 0.9963390231132507)]
# ...
