# %% [markdown]
# # Imports

# %%
#Imports and installs
import transformers
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
import transformers
from craft_text_detector import Craft # Need to edit the saving function to prepend 0's
import requests 
import torch
import os, random
from PIL import Image,ImageFilter
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets
from torch.utils.data import Dataset
from tqdm import tqdm
import pandas as pd

import numpy as np
import imghdr
import pickle
from pathlib import Path
import cv2
import torch.nn.functional as F
import multiprocessing
from functools import partial
import json

import matplotlib.pyplot as plt
import warnings
import time

import trocr
import matching
import predictions
import results

from taxonerd import TaxoNERD

# %% [markdown]
# # Directories

# %%
# Suppressing all the huggingface warnings
SUPPRESS = True
if SUPPRESS:
    from transformers.utils import logging
    logging.set_verbosity(40)
# Turning off this warning, isn't relevant for this application
warnings.filterwarnings("ignore", "(Possibly )?corrupt EXIF data", UserWarning)

# Location of images
workdir = '/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/TROCR_Training/goodfiles/' # update this to the desired directory on scc
# Location of the segmentations
output_dir_craft = '/projectnb/sparkgrp/kabilanm/goodfilescraft/'
# Location to save all output files
save_dir = '/usr4/ds549/kabilanm/saved_results/'
# For ground truth labels 
workdir2 = '/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/scraped-data/drago_testdata/gt_labels' # update this to the desired directory on scc

# Corpus files
ALL_SPECIES_FILE = '/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/corpus_taxon/output/possible_species.pkl'
ALL_GENUS_FILE = '/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/corpus_taxon/output/possible_genus.pkl'
# ALL_TAXON_FILE = '/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-new/ml-herbarium/corpus/corpus_taxon/corpus_taxon.txt'
ALL_TAXON_FILE = '/usr4/ds549/kabilanm/ml-herbarium/corpus/corpus_taxon/corpus_taxon.txt'

# %% [markdown]
# # Running craft and saving the segmented images

# %%
count = 0
for filename in tqdm(sorted(os.listdir(workdir))):
    count +=1

print(count)
# Out:
# 100%|██████████| 254/254 [00:00<00:00, 2536555.28it/s]
# 254

# %%
# initialize the CRAFT model
craft = Craft(output_dir = output_dir_craft,export_extra = False, text_threshold = .7,link_threshold = .4, crop_type="poly",low_text = .3,cuda = True)

# CRAFT on images to get bounding boxes
images = []
corrupted_images = []
no_segmentations = []
boxes = {}
count= 0
img_name = []
box = []
file_types = (".jpg", ".jpeg",".png")
    
for filename in tqdm(sorted(os.listdir(workdir))):
    if filename.endswith(file_types):
        image = workdir+filename
        try:
            img = Image.open(image) 
            img.verify() # Check that the image is valid
            bounding_areas = craft.detect_text(image)
            if len(bounding_areas['boxes']): #check that a segmentation was found
                images.append(image)
                boxes[image] = bounding_areas['boxes']
                
            else:
                no_segmentations.append(image)
        except (IOError, SyntaxError) as e:
            corrupted_images.append(image)
# Out:
# /projectnb/ds549/students/kabilanm/.conda/envs/BNER_py39/lib/python3.9/site-packages/torchvision/models/_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and may be removed in the future. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# /projectnb/ds549/students/kabilanm/.conda/envs/BNER_py39/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /projectnb/ds549/students/kabilanm/.conda/envs/BNER_py39/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   1%|          | 2/254 [00:04<07:32,  1.80s/it]/projectnb/ds549/students/kabilanm/.conda/envs/BNER_py39/lib/python3.9/site-packages/craft_text_detector/craft_utils.py:415: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   polys = np.array(polys)
# /projectnb/ds549/students/kabilanm/.conda/envs/BNER_py39/lib/python3.9/site-packages/craft_text_detector/predict.py:110: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   polys_as_ratio = np.array(polys_as_ratio)
# 100%|██████████| 254/254 [11:06<00:00,  2.62s/it]

# %% [markdown]
# # Getting all the segmented images into a dataloader, and loading model and processor for trocr

# %%
# Deleting empty folders, which occurs if some of the images get no segementation from CRAFT
root = output_dir_craft
folders = list(os.walk(root))[1:]
deleted = []
for folder in folders:
    if not folder[2]:
        deleted.append(folder)
        os.rmdir(folder[0])
        
# Setting up the Tr-OCR model and processor
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten") 
model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten").to(device)

# Use all available gpu's
model_gpu= nn.DataParallel(model,list(range(torch.cuda.device_count()))).to(device)

# Dataloader for working with gpu's
trainset = datasets.ImageFolder(output_dir_craft, transform = processor)
testloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=False)

# For matching words to image
filenames = [s.replace('_crops', '') for s in list(trainset.class_to_idx)]

# For matching the image name with the label name
word_log_dic = {k: v for k,v in enumerate(filenames)}
# For matching the image name with the transriptions
words_identified = {k: [] for v,k in enumerate(filenames)}

# %% [markdown]
# # Saving the filenames, word_log_dic and words_identified

# %%
# Save filenames
with open(save_dir+'filenames.txt', 'w') as fp:
    for item in filenames:
        # write each item on a new line
        fp.write("%s\n" % item)
# Save word_log_dic 
with open(save_dir+'word_log_dic.json', 'w') as fp:
    json.dump(word_log_dic, fp)
# Save words_identified
with open(save_dir+'words_identified.json', 'w') as fp:
    json.dump(words_identified, fp)

# %% [markdown]
# # Running Tr-OCR on the Segmented Images from Craft

# %%
#Storing the outputs
results,confidence,labels = trocr.evaluate_craft_seg(model,processor, words_identified,word_log_dic,testloader,device)
#Saving all the outputs in dataframe
df = pd.DataFrame(list(zip(results,confidence,labels)),columns = ['Results','Confidence','Labels'])
df.to_pickle(save_dir+'full_results.pkl')
# Out:
# Transcribing Image Segments:   0%|          | 0/341 [00:00<?, ?it/s]/projectnb/ds549/students/kabilanm/.conda/envs/BNER_py39/lib/python3.9/site-packages/transformers/generation_utils.py:1359: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Transcribing Image Segments: 100%|██████████| 341/341 [04:57<00:00,  1.15it/s]

# %%
# First part of final csv with results, confidence level from tr-ocr, and label
combined_df = trocr.combine_by_label(df)

# Adding the image path and all bounding boxes 

df_dictionary = pd.DataFrame(boxes.items(), columns=['Image_Path', 'Bounding_Boxes'])
combined_df = pd.concat([combined_df, df_dictionary], axis=1, join='inner')
display(combined_df.head())
# Out:
#    Labels                                      Transcription  \
# 0       0  [Museum d'Histoire naturelle de Paris, Herbier...
# 1       1  [100s, 100p, 0, 100p., 2nd, 100,, top, 100, 10...
# 2       2  [0-, 100,, ed state., 1627083, United States n...
# 3       3  [us, 8.810, own, copyright reserved, 1685951, ...
# 4       4  [100, flora of the, Washington Baltimore area,...
#
#                             Transcription_Confidence  \
# 0  [0.8803507685661316, 0.9324854016304016, 0.997...
# 1  [0.03950851410627365, 0.061212457716464996, 0....
# 2  [0.039854906499385834, 0.11935094743967056, 0....
# 3  [0.361989825963974, 0.2914508879184723, 0.2818...
# 4  [0.05119089409708977, 0.6536547541618347, 0.98...
#
#                                           Image_Path  \
# 0  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...
# 1  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...
# 2  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...
# 3  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...
# 4  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...
#
#                                       Bounding_Boxes
# 0  [[[3858.9062, 280.7068], [5929.0693, 357.37952...
# 1  [[[6485.1157, 425.71875], [6612.831, 425.71875...
# 2  [[[6399.1187, 307.38126], [6524.8657, 307.3812...
# 3  [[[3286.3594, 168.53125], [3539.1562, 168.5312...
# 4  [[[6408.428, 710.46875], [6536.3125, 710.46875...

# %%
#Save intermediate file
combined_df.to_pickle(save_dir+'/test.pkl')

# %% [markdown]
# # Use TaxoNERD to recognize taxons from detected text

# %%
taxonerd = TaxoNERD(prefer_gpu=False) # set to "true" if GPU is accessible

nlp = taxonerd.load(
    model="en_core_eco_biobert", 
    linker="ncbi_taxonomy", 
    threshold=0
)

# %%
count = 0
output = []
taxon_output = []

# test "gbif_backbone" linker -> more species here
# use BERT for person and location

# predict taxons for text detected from each image
for index, row in combined_df.iterrows():
    temp = row["Transcription"]
    
    # construct a single string out of all the detected text
    input_text = " ".join(temp) 
    doc = taxonerd.find_in_text(input_text)
    
    try:
        print("Linked name: ", doc.entity[0][0][1], " -> Confidence: ", doc.entity[0][0][2])
        count+=1
        
        # append linked taxon entity
        taxon_output.append(str(doc.entity[0][0][1]))
        
    except AttributeError:
        # append empty strings when no entity is detected
        taxon_output.append("")
# Out:
# Linked name:  Ferraria  -> Confidence:  0.6746945977210999
# Linked name:  Chlopsis fierasfer  -> Confidence:  0.448846697807312
# Linked name:  Clermontia persicifolia  -> Confidence:  0.6184449195861816
# Linked name:  Elymus hystrix L.  -> Confidence:  0.7790964841842651
# Linked name:  Bucculatrix clavenae  -> Confidence:  0.38107770681381226
# Linked name:  Hohenbergia antillana Mez  -> Confidence:  0.9376682043075562
# Linked name:  Nectria austroamericana  -> Confidence:  0.6761608719825745
# Linked name:  Abbottella abbotti  -> Confidence:  0.6212729811668396
# Linked name:  Hysterium herbarum  -> Confidence:  0.5404318571090698
# Linked name:  Plasmodium hispaniolae  -> Confidence:  0.7043249011039734
# Linked name:  Argythamnia  -> Confidence:  0.6870838403701782
# Linked name:  Tripsacum maizar  -> Confidence:  0.7003204226493835
# Linked name:  Drymaria cordata  -> Confidence:  0.5393434166908264
# Linked name:  Phyllanthus acidus  -> Confidence:  0.7807743549346924
# Linked name:  Asclepias subverticillata  -> Confidence:  0.7819554209709167
# Linked name:  Swallenia  -> Confidence:  0.6012974977493286
# Linked name:  Sida jussiaeana  -> Confidence:  0.6760076880455017
# Linked name:  Ectenagena  -> Confidence:  0.5516428351402283
# Linked name:  Phyllanthus  -> Confidence:  0.5286953449249268
# Linked name:  Serjania  -> Confidence:  0.5968989133834839
# Linked name:  Miconia  -> Confidence:  0.6022593379020691
# Linked name:  Frankenia  -> Confidence:  0.34963351488113403
# Linked name:  Chrysophyllum  -> Confidence:  0.7363256812095642
# Linked name:  Phymata pacifica pacifica  -> Confidence:  0.5058398246765137
# Linked name:  Arboretum virus  -> Confidence:  0.7156985402107239
# Linked name:  Varronia linnaei  -> Confidence:  0.688494086265564
# Linked name:  Castilleja nana Eastw.  -> Confidence:  0.6814929246902466
# Linked name:  Dalea polygonoides  -> Confidence:  0.4700760841369629
# Linked name:  Albizia  -> Confidence:  0.5476952195167542
# Linked name:  Codiaceae  -> Confidence:  0.47564220428466797
# Linked name:  Tapirira mexicana Marchand  -> Confidence:  0.4807157516479492
# Linked name:  Bacillus berolinensis  -> Confidence:  0.44208478927612305
# Linked name:  Hysterium herbarum  -> Confidence:  0.36432766914367676
# Linked name:  Lunella  -> Confidence:  0.47642695903778076
# Linked name:  Antonia  -> Confidence:  0.3880206346511841
# Linked name:  Polystichum lehmannii  -> Confidence:  0.8619676232337952
# Linked name:  Passifloraceae  -> Confidence:  1.0
# Linked name:  Chiococca  -> Confidence:  0.4689680337905884
# Linked name:  Mugil cephalus encephalitis virus  -> Confidence:  0.4773622751235962
# Linked name:  Renata canaanensis  -> Confidence:  0.6127102375030518
# Linked name:  Inopsis modulata  -> Confidence:  0.572173535823822
# Linked name:  Solanum jamesii Torr.  -> Confidence:  0.8215755224227905
# Linked name:  Iris hartwegii subsp. hartwegii  -> Confidence:  0.5727243423461914
# Linked name:  hierba del sapo  -> Confidence:  0.5251346230506897
# Linked name:  Echinopepon insularis  -> Confidence:  0.7114951014518738
# Linked name:  Castilleja  -> Confidence:  0.7600851058959961
# Linked name:  Brachyotum nutans  -> Confidence:  0.8329945206642151
# Linked name:  Piperaceae  -> Confidence:  0.5346519351005554
# Linked name:  Cirsium muticum Michx.  -> Confidence:  0.805268406867981
# Linked name:  Limonia  -> Confidence:  0.6607179641723633
# Linked name:  Peperomia microphylla  -> Confidence:  0.8046175241470337
# Linked name:  Herbertaceae  -> Confidence:  0.58149254322052
# Linked name:  Acer saccharum Marshall  -> Confidence:  0.8465409278869629
# Linked name:  Hericium americanum  -> Confidence:  0.7309022545814514
# Linked name:  Rhus succedanea  -> Confidence:  0.33900201320648193
# Linked name:  Gentiana saponaria L.  -> Confidence:  0.9999999403953552
# Linked name:  American shoreweed  -> Confidence:  0.5638174414634705
# Linked name:  Barbarea verna  -> Confidence:  0.43578481674194336
# Linked name:  Pleospora herbarum var. herbarum  -> Confidence:  0.35010361671447754
# Linked name:  Gaylussacia  -> Confidence:  0.5872423052787781
# Linked name:  Delphinium purpusii Brandegee  -> Confidence:  0.7701128125190735
# Linked name:  Heliotropium  -> Confidence:  0.5390904545783997
# Linked name:  Arboretum virus  -> Confidence:  0.921684205532074
# Linked name:  Stelis trichostoma  -> Confidence:  0.7336957454681396
# Linked name:  Carex gigas  -> Confidence:  0.6478211283683777
# Linked name:  Poa asperiflora  -> Confidence:  0.5904759764671326
# Linked name:  Aelia  -> Confidence:  0.6071582436561584
# Linked name:  Chimaphila menziesii  -> Confidence:  0.5984134078025818
# Linked name:  Monorthochaeta  -> Confidence:  0.36404645442962646
# Linked name:  Vesta  -> Confidence:  0.4949744939804077
# Linked name:  Agrostis stolonifera  -> Confidence:  0.6864585876464844
# Linked name:  Pilea  -> Confidence:  0.3772147297859192
# Linked name:  Negundo aceroides  -> Confidence:  1.0
# Linked name:  Cronobacter dublinensis subsp. dublinensis  -> Confidence:  0.620320200920105
# Linked name:  Neglecta  -> Confidence:  0.71709805727005
# Linked name:  Pleospora herbarum var. herbarum  -> Confidence:  0.38966667652130127
# Linked name:  Tanycaula  -> Confidence:  0.567577600479126
# Linked name:  Amelanchier laevis  -> Confidence:  0.8323909640312195
# Linked name:  Cincinnatia  -> Confidence:  0.7305887341499329
# Linked name:  great seahorse  -> Confidence:  0.5255922079086304
# Linked name:  Hamamelis virginiana L.  -> Confidence:  0.7398872971534729
# Linked name:  American larch  -> Confidence:  0.4630253314971924
# Linked name:  Carex laxiculmis Schwein.  -> Confidence:  0.842528760433197
# Linked name:  Arctostaphylos  -> Confidence:  0.5659177303314209
# Linked name:  Spiraea salicifolia L.  -> Confidence:  0.4300501346588135
# Linked name:  Pleospora herbarum var. herbarum  -> Confidence:  0.49797844886779785
# Linked name:  Mediasia  -> Confidence:  0.6457584500312805
# Linked name:  Scirpus  -> Confidence:  1.0
# Linked name:  Sanguina  -> Confidence:  0.3790479302406311
# Linked name:  Ogataea angusta  -> Confidence:  0.5520999431610107
# Linked name:  Pleospora herbarum var. herbarum  -> Confidence:  0.4242549538612366
# Linked name:  Ryvardenia  -> Confidence:  0.468233585357666
# Linked name:  Pleospora herbarum var. herbarum  -> Confidence:  0.48543691635131836
# Linked name:  Encelia canescens  -> Confidence:  0.4109538197517395
# Linked name:  Crataegus uniflora Muenchh.  -> Confidence:  0.8404030799865723
# Linked name:  Ligia sp. San Diego  -> Confidence:  0.40366894006729126
# Linked name:  Crepis acuminata  -> Confidence:  0.8123509287834167
# Linked name:  Viola striata  -> Confidence:  0.6035284399986267
# Linked name:  Parodianthus Tronc.  -> Confidence:  0.4024094343185425
# Linked name:  Phillips  -> Confidence:  0.6297792792320251
# Linked name:  mareer  -> Confidence:  0.4885854721069336
# Linked name:  Ferruginivarius  -> Confidence:  0.3572755455970764
# Linked name:  Cressa  -> Confidence:  0.5450975298881531
# Linked name:  Lachlania saskatchewanensis  -> Confidence:  0.7440516352653503
# Linked name:  Potamogeton diversifolius  -> Confidence:  0.9181922078132629
# Linked name:  Antaea  -> Confidence:  0.45312297344207764
# Linked name:  Elasmucha  -> Confidence:  0.29791349172592163
# Linked name:  Macropiper puberulum  -> Confidence:  0.9441685080528259
# Linked name:  Miconia calvescens  -> Confidence:  0.6508199572563171
# Linked name:  Abuta grandifolia  -> Confidence:  0.7207111716270447
# Linked name:  Spermophilus mexicanus mexicanus  -> Confidence:  0.6533426642417908
# Linked name:  Protea  -> Confidence:  0.5033712387084961
# Linked name:  Labisia pumila  -> Confidence:  0.574959397315979
# Linked name:  Vitex oxycuspis  -> Confidence:  0.2867979407310486
# Linked name:  Vitis rotundifolia var. rotundifolia  -> Confidence:  0.6532357335090637
# Linked name:  Meles canescens  -> Confidence:  0.4659111499786377
# Linked name:  Acourtia  -> Confidence:  0.6081783771514893
# Linked name:  Tibouchina mollis (Bonpl.) Cogn., 1885  -> Confidence:  0.583233118057251
# Linked name:  Elliottia  -> Confidence:  1.0
# Linked name:  Donnellsmithia juncea  -> Confidence:  0.8114708662033081
# Linked name:  Convolvulus sepium  -> Confidence:  0.7898058891296387
# Linked name:  Ramphocelus costaricensis costaricensis  -> Confidence:  0.43999171257019043
# Linked name:  Arctostaphylos crustacea  -> Confidence:  1.0
# Linked name:  Comarostaphylis diversifolia (Parry) Greene  -> Confidence:  0.5839959383010864
# Linked name:  Rhabdodendron  -> Confidence:  0.5702385306358337
# Linked name:  Christia  -> Confidence:  0.8567053079605103
# Linked name:  Pleospora herbarum var. herbarum  -> Confidence:  0.48543691635131836
# Linked name:  Blephilia hirsuta  -> Confidence:  0.6338210105895996
# Linked name:  Calicina mariposa  -> Confidence:  0.5119643211364746
# Linked name:  Piper retrofractum  -> Confidence:  0.5950607061386108
# Linked name:  Hieracium longipilum  -> Confidence:  0.8372793793678284
# Linked name:  Trifolium montanum subsp. montanum  -> Confidence:  0.8448832631111145
# Linked name:  Sebaea grisebachiana  -> Confidence:  0.6047921180725098
# Linked name:  Lipinia pulchella pulchella  -> Confidence:  0.6844646334648132
# Linked name:  Phaner  -> Confidence:  0.5677723288536072
# Linked name:  Pennella  -> Confidence:  0.3952885866165161
# Linked name:  Elaphoglossum  -> Confidence:  1.0
# Linked name:  vectors  -> Confidence:  0.3779962658882141
# Linked name:  Mangifera indica  -> Confidence:  0.9278707504272461
# Linked name:  Phyla cuneifolia  -> Confidence:  0.684518575668335
# Linked name:  fruit fly  -> Confidence:  1.0
# Linked name:  Solanum boliviense  -> Confidence:  0.3886442184448242
# Linked name:  Elysius  -> Confidence:  0.6750582456588745
# Linked name:  Stimula  -> Confidence:  0.5318304300308228
# Linked name:  Glaux maritima  -> Confidence:  0.901401937007904
# Linked name:  Epipactis  -> Confidence:  0.629652202129364
# Linked name:  Agalinis maritima  -> Confidence:  0.5445537567138672
# Linked name:  Cuscuta  -> Confidence:  1.0
# Linked name:  boneset  -> Confidence:  0.4732562303543091
# Linked name:  amaranth  -> Confidence:  0.4547901153564453
# Linked name:  Larus philadelphia  -> Confidence:  0.513018786907196
# Linked name:  Nacarina cordillera  -> Confidence:  0.3647933006286621
# Linked name:  Trigonella americana Nutt.  -> Confidence:  0.3943467140197754
# Linked name:  Drosera lanata  -> Confidence:  0.38788938522338867
# Linked name:  Scotia  -> Confidence:  0.432304322719574
# Linked name:  Olea laxiflora  -> Confidence:  0.580146074295044
# Linked name:  Cicadosa cicadoides  -> Confidence:  0.45311611890792847
# Linked name:  Silene douglasii Hook.  -> Confidence:  0.7508146166801453
# Linked name:  Claytonia rubra  -> Confidence:  0.8812231421470642
# Linked name:  Hericium americanum  -> Confidence:  0.7309022545814514
# Linked name:  Ranunculus hispidus  -> Confidence:  0.621273934841156
# Linked name:  Trachys  -> Confidence:  0.40033984184265137
# Linked name:  Clematis ligusticifolia Nutt.  -> Confidence:  0.8620135188102722
# Linked name:  Penicillium cantabricum  -> Confidence:  0.5637029409408569
# Linked name:  Menispermaceae  -> Confidence:  0.7682653069496155
# Linked name:  nasturtium  -> Confidence:  0.7672325968742371
# Linked name:  Ranunculus fascicularis  -> Confidence:  0.6079950332641602
# Linked name:  Oxalis gracilipes  -> Confidence:  0.4100130796432495
# Linked name:  Clematis confusa Grey-Wilson  -> Confidence:  0.5576809644699097
# Linked name:  Parnassia  -> Confidence:  0.8788698315620422
# Linked name:  Saxifraga bronchialis subsp. bronchialis  -> Confidence:  0.7451374530792236
# Linked name:  Philadelphus microphyllus  -> Confidence:  0.8987383842468262
# Linked name:  Crataegus  -> Confidence:  0.6192188858985901
# Linked name:  Crataegus brainerdii  -> Confidence:  0.892955482006073
# Linked name:  Acaena cylindristachya Ruiz & Pav.  -> Confidence:  0.81285160779953
# Linked name:  Noveria virus  -> Confidence:  0.42492979764938354
# Linked name:  Quercus alba  -> Confidence:  1.0
# Linked name:  Prunus glandulosa  -> Confidence:  0.8184100389480591
# Linked name:  Pleospora herbarum var. herbarum  -> Confidence:  0.45806562900543213
# Linked name:  Trifolium latifolium  -> Confidence:  0.5871572494506836
# Linked name:  Gittenbergeria  -> Confidence:  0.46099257469177246
# Linked name:  Nectandra  -> Confidence:  0.6225635409355164
# Linked name:  Carex barrattii  -> Confidence:  0.6030243039131165
# Linked name:  Cyperus odoratus L.  -> Confidence:  1.0
# Linked name:  Viburnum nudum L.  -> Confidence:  0.7718217968940735
# Linked name:  Barbarea grayi  -> Confidence:  0.4115913510322571
# Linked name:  Potamogeton gramineus L.  -> Confidence:  1.0
# Linked name:  Maianthemum stellatum  -> Confidence:  0.7861543297767639
# Linked name:  Yucca schottii Engelm.  -> Confidence:  0.8786598443984985
# Linked name:  Xerophyllum asphodeloides  -> Confidence:  0.8339893817901611
# Linked name:  Columba malherbii  -> Confidence:  0.44413721561431885
# Linked name:  Agalinis tenella Pennell  -> Confidence:  0.5576672554016113
# Linked name:  Eragrostis intermedia  -> Confidence:  0.6129094362258911
# Linked name:  Festuca myuros  -> Confidence:  0.9183596968650818
# Linked name:  Stipa przewalskyi  -> Confidence:  0.5922273993492126
# Linked name:  Panicum  -> Confidence:  0.605443000793457
# Linked name:  Hyla multiplica  -> Confidence:  0.32026731967926025
# Linked name:  Eutrochium fistulosum  -> Confidence:  0.74272620677948
# Linked name:  Fabaceae  -> Confidence:  0.6787852644920349
# Linked name:  New Kent County virus  -> Confidence:  0.47466981410980225
# Linked name:  Agrostis stolonifera L.  -> Confidence:  0.9999999403953552
# Linked name:  Cinna arundinacea  -> Confidence:  0.9082254767417908
# Linked name:  Blochmannia  -> Confidence:  0.5579192638397217
# Linked name:  Hippotis  -> Confidence:  0.7650855183601379
# Linked name:  Canarium fusiforme  -> Confidence:  0.5123065114021301
# Linked name:  Aristida  -> Confidence:  0.4937598705291748
# Linked name:  Paspalum  -> Confidence:  0.6592668890953064
# Linked name:  Panicum stapfianum  -> Confidence:  0.8416372537612915
# Linked name:  Adleria  -> Confidence:  0.6423677802085876
# Linked name:  Oscillatoria calcuttensis  -> Confidence:  0.5200969576835632
# Linked name:  Arboretum virus  -> Confidence:  0.921684205532074
# Linked name:  Stellaria graminea  -> Confidence:  0.5211858153343201
# Linked name:  Ania angustifolia  -> Confidence:  0.918615460395813
# Linked name:  Lantana depressa var. depressa  -> Confidence:  0.5537779331207275
# Linked name:  Vicia americana  -> Confidence:  1.0
# Linked name:  Muhlenbergia richardsonis (Trin.) Rydb.  -> Confidence:  0.8281458616256714
# Linked name:  Mexican orange  -> Confidence:  0.564281165599823
# Linked name:  Polygonum persicaria L.  -> Confidence:  1.0
# Linked name:  Coelogyne  -> Confidence:  0.4729166030883789
# Linked name:  Musci  -> Confidence:  0.726667582988739
# Linked name:  Juncus dudleyi Wiegand  -> Confidence:  0.8714792132377625
# Linked name:  Schlechteria  -> Confidence:  0.738267183303833

# %%
print(count)
print(len(taxon_output))
# Out:
# 222
# 249

# %%
combined_df["Taxon_Output"] = taxon_output

combined_df[["Image_Path", "Taxon_Output"]].head()
# Out:
#                                           Image_Path             Taxon_Output
# 0  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...                 Ferraria
# 1  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...       Chlopsis fierasfer
# 2  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...  Clermontia persicifolia
# 3  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...
# 4  /projectnb/sparkgrp/ml-herbarium-grp/ml-herbar...        Elymus hystrix L.

# %%
print(taxon_output[:10])
# Out:
# ['Ferraria', 'Chlopsis fierasfer', 'Clermontia persicifolia', '', 'Elymus hystrix L.', 'Bucculatrix clavenae', 'Hohenbergia antillana Mez', 'Nectria austroamericana', 'Abbottella abbotti', '']

# %% [markdown]
# # Reading in the ground truth files for tested images

# %%
# Reading in the ground truth values

gt_t = workdir2+'/taxon_gt.txt'
Taxon_truth = { line.split(":")[0] : line.split(": ")[1].strip() for line in open(gt_t) }

gt_g = workdir2+'/geography_gt.txt'
Geography_truth = { line.split(":")[0] : line.split(": ")[1].strip() for line in open(gt_g) }

gt_c = workdir2+'/collector_gt.txt'
Collector_truth = { line.split(":")[0] : line.split(": ")[1].strip() for line in open(gt_c) }

comparison_file = {"Taxon":Taxon_truth,"Countries":Geography_truth,"Collector":Collector_truth}

# %%
Taxon_truth_sample = {k: Taxon_truth[k] for k in list(Taxon_truth)[:10]}

# view subset of the taxon truth
print(Taxon_truth_sample)
# Out:
# {'1697659851': 'Euphrasia officinalis', '2573258025': 'Bryoerythrophyllum recurvirostrum', '2597666444': 'Carduus tenuiflorus', '1931288980': 'Agoseris parviflora', '1930241969': 'Spiraea canescens', '1929944910': 'Chylismia scapoidea', '1931007576': 'Carex typhina', '1928514234': 'Stachys hispida', '1928658806': 'Solanum donianum', '1931124118': 'Suaeda nigra'}

# %%
# utility functions for finding cosine similarity

def word2vec(word):
    from collections import Counter
    from math import sqrt

    # count the characters in word
    cw = Counter(word)
    # precomputes a set of the different characters
    sw = set(cw)
    # precomputes the "length" of the word vector
    lw = sqrt(sum(c*c for c in cw.values()))

    # return a tuple
    return cw, sw, lw

def cosdis(v1, v2):
    # which characters are common to the two words?
    common = v1[1].intersection(v2[1])
    # by definition of cosine distance we have
    return sum(v1[0][ch]*v2[0][ch] for ch in common)/v1[2]/v2[2]

# %% [markdown]
# # Checking Accuracy Against Taxon Truth File

# %%
# generate list of similarity thresholds
sim_threshold = np.arange(0.1, 1, 0.1)

accuracy_at_different_thresh = []

# compute similarity scores
cosine_sim = []

for index, row in combined_df.iterrows():
    
    # extract image name from the dataframe
    img_name = row["Image_Path"].split("/")[-1][:-4]
    taxon_predicted = row["Taxon_Output"]
    taxon_gt = Taxon_truth[img_name]
    
    # compute cosine similarity between the predicted taxon and ground truth
    try:
        sim = cosdis(word2vec(taxon_gt), word2vec(taxon_predicted))
        cosine_sim.append(sim)
        # print(taxon_gt, taxon_predicted, sim)
        
    except ZeroDivisionError:
        cosine_sim.append(0)
        # print(taxon_gt, taxon_predicted,"0")

# append similarity scores to the dataframe
combined_df["Cosine_Similarity"] = cosine_sim

final_taxon_prediction = pd.DataFrame(columns=["Threshold", "Taxons_Predicted"])

#  compute prediction accuracy at each similarity threshold
for threshold in sim_threshold:
    acc_count = (combined_df["Cosine_Similarity"] > threshold).sum()
    acc_val = acc_count/combined_df.shape[0]    
    
    temp = [threshold, acc_count]
    final_taxon_prediction.loc[len(final_taxon_prediction)] = temp
    
final_taxon_prediction
# Out:
#    Threshold  Taxons_Predicted  Taxon_Accuracy_Predicted
# 0        0.1             222.0                  0.891566
# 1        0.2             221.0                  0.887550
# 2        0.3             219.0                  0.879518
# 3        0.4             208.0                  0.835341
# 4        0.5             192.0                  0.771084
# 5        0.6             167.0                  0.670683
# 6        0.7             131.0                  0.526104
# 7        0.8              95.0                  0.381526
# 8        0.9              66.0                  0.265060
