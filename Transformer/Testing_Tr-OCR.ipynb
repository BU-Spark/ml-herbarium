# %%
#Imports and installs
import transformers
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
# !pip install craft-text-detector
import transformers
from craft_text_detector import Craft
import requests 
import torch
import os, random
from PIL import Image
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets
from tqdm import tqdm
import pandas as pd
import numpy as np
import imghdr
import pickle
from pathlib import Path
import cv2
import torch.nn.functional as F
import multiprocessing
from functools import partial

# %%
# Set COLAB = False if running on SCC
COLAB = False

#suppressing all the huggingface warnings
SUPPRESS = True
if SUPPRESS:
    from transformers.utils import logging
    logging.set_verbosity(40)

# %%
if COLAB:
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount = True)
    workdir = '/content/gdrive/MyDrive/testing-trocr'
    output_dir_craft = '/content/gdrive/MyDrive/craft/'
else:
    workdir = '/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/scraped-data/drago_testdata' # update this to the desired directory on scc
    output_dir_craft = '/usr3/graduate/colejh/craft/'

# %%
# initialize the CRAFT model
craft = Craft(output_dir = output_dir_craft,export_extra = False, text_threshold = .8,link_threshold = .6, crop_type="poly",low_text = .5,cuda = True)

# %% [markdown]
# # Running craft and saving the segmented images

# %%
# CRAFT on images to get bounding boxes
images = []
corrupted_images = []
no_segmentations = []
boxes = {}
count= 0
file_types = (".jpg", ".jpeg",".png")
for filename in tqdm(os.listdir(workdir)):
    if filename.endswith(file_types):
        image = workdir+'/'+filename
        try:
            img = Image.open(image) 
            img.verify() # Check that the image is valid
            bounding_areas = craft.detect_text(image)
            if not bounding_areas: #check that a segmentation was found
                no_segmentations.append(image)
            else:
                images.append(image)
                boxes[image] = bounding_areas['boxes']
        except (IOError, SyntaxError) as e:
            corrupted_images.append(image)

            
#     count +=1
#     # Using count for time being to get things working, remove once setup is complete
#     if count == 5:
#         break
# Out:
#   0%|          | 1/1018 [00:00<14:57,  1.13it/s]/usr3/graduate/colejh/.local/lib/python3.8/site-packages/craft_text_detector/craft_utils.py:415: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   polys = np.array(polys)
# /usr3/graduate/colejh/.local/lib/python3.8/site-packages/craft_text_detector/predict.py:110: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   polys_as_ratio = np.array(polys_as_ratio)
#   7%|▋         | 70/1018 [01:14<15:24,  1.03it/s]/share/pkg.7/python3/3.8.10/install/lib/python3.8/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11 bytes but only got 6. Skipping tag 42037
#   warnings.warn(
#  39%|███▉      | 401/1018 [06:34<08:03,  1.28it/s]/share/pkg.7/python3/3.8.10/install/lib/python3.8/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 14 bytes but only got 8. Skipping tag 42036
#   warnings.warn(
#  88%|████████▊ | 898/1018 [15:12<01:42,  1.18it/s]/share/pkg.7/python3/3.8.10/install/lib/python3.8/site-packages/PIL/TiffImagePlugin.py:785: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 10.
#   warnings.warn(str(msg))
# 100%|██████████| 1018/1018 [16:54<00:00,  1.00it/s]

# %% [markdown]
# # Getting all the segemnted images into a dataloader, and loading model and processor for trocr

# %%
# Deleting empty folders
root = output_dir_craft
folders = list(os.walk(root))[1:]
deleted = []
for folder in folders:
    # folder example: ('FOLDER/3', [], ['file'])
    if not folder[2]:
        deleted.append(folder)
        os.rmdir(folder[0])
# Setting up the Tr-OCR model (using base model currently, large takes much longer)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten") 
model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")

# Use all available gpu's
model_gpu= nn.DataParallel(model).to(device)

# Dataloader for working with gpu's
trainset = datasets.ImageFolder(output_dir_craft, transform = processor)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True)# for i, data in enumerate(trainloader):

# For matching words to image
filenames = [s.replace('_crops', '') for s in list(trainset.class_to_idx)]
word_log_dic = {k: v for k,v in enumerate(filenames)}
words_identified = {k: [] for v,k in enumerate(filenames)}

# %%
# Yoinked https://github.com/rsommerfeld/trocr/blob/main/src/scripts.py

def get_confidence_scores(generated_ids):
    # Get raw logits, with shape (examples,tokens,token_vals)
    logits = generated_ids.scores
    logits = torch.stack(list(logits),dim=1)

    # Transform logits to softmax and keep only the highest (chosen) p for each token
    logit_probs = F.softmax(logits, dim=2)
    char_probs = logit_probs.max(dim=2)[0]

    # Only tokens of val>2 should influence the confidence. Thus, set probabilities to 1 for tokens 0-2
    mask = generated_ids.sequences[:,:-1] > 2
    char_probs[mask] = 1

    # Confidence of each example is cumulative product of token probs
    batch_confidence_scores = char_probs.cumprod(dim=1)[:, -1]
    return [v.item() for v in batch_confidence_scores]

# %%
def evaluate_craft_seg(model,trainloader):
    results = []
    confidence = []
    label = []

    model_gpu.eval()
    with torch.no_grad():
        for idx,data in enumerate(tqdm(trainloader)):

            images, labels = data
            images, labels = images['pixel_values'][0].to(device), labels.to(device)

            decoded = model_gpu.module.generate(images,return_dict_in_generate = True, output_scores = True) 
            final_values = processor.batch_decode(decoded.sequences, skip_special_tokens=True)


            confidences = get_confidence_scores(decoded)

            for idx,value in enumerate(labels.cpu().numpy()):
#           if confidences[idx]>.8: # to cull some of the really terrible guesses, probably want to do this in the search function instead
                words_identified[word_log_dic[value]].append(final_values[idx])
            
            results.extend(final_values)
            confidence.extend(confidences)
            label.extend(labels.cpu().numpy())

    return results,confidence,label

# %%
#Storing the outputs
results,confidence,labels = evaluate_craft_seg(model,trainloader)
df = pd.DataFrame(list(zip(results,confidence,labels)),columns = ['Results','Confidence','Labels'])
df.to_pickle('results7.pkl')
# Out:
#   0%|          | 0/1552 [00:00<?, ?it/s]/usr3/graduate/colejh/.local/lib/python3.8/site-packages/transformers/generation_utils.py:1353: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 100%|██████████| 1552/1552 [22:33<00:00,  1.15it/s]

# %%
def load_pickle(filepath):
    filepkl = open(filepath, "rb")

    # Unpickle the objects

    unpickled = pickle.load(filepkl)
    
    return unpickled

# %%
a = load_pickle('/usr3/graduate/colejh/'+'results5.pkl')
results =pd.Series(a.Results)
labels = list(a['Labels'])

# %%
# String matching installs
# !pip install --force-reinstall numpy==1.18.5 # need this to work the string grouper
# !pip install numpy
# !pip install string-grouper

from string_grouper import match_strings, match_most_similar

# %%
if COLAB:
    taxon_file = '/content/gdrive/MyDrive/corpus_taxon.txt'
else:
    taxon_file = workdir+'/taxon_corpus.txt'
    geography_file = workdir+'/geography_corpus.txt'
    collector_file = workdir+'/collector_corpus.txt'
taxon = pd.read_csv(taxon_file, delimiter = "\t", names=["Taxon"]).squeeze()
geography = pd.read_csv(geography_file, delimiter = "\t", names=["Geography"]).squeeze()
collector = pd.read_csv(collector_file, delimiter = "\t", names=["Collector"]).squeeze()

# %%
# String matching
minimum_similarity = .1
results_series = pd.Series(results)
taxon = pd.read_csv(taxon_file, delimiter = "\t", names=["Taxon"]).squeeze()
 
start = time.time()
matches = match_strings(taxon,results_series,n_blocks = 'guess',min_similarity = minimum_similarity,max_n_matches = 4)
end = time.time()
print('time',end-start)

# %%
def match(main,comparison_file,minimum_similarity):
     # Function takes a main file containing strings, a comparison file to match against main,
     #  and a minimum similarity confidence level. Returns a list of matches based on similarity.

    if not isinstance(comparison_file, pd.Series):

        comparison_file = pd.Series(comparison_file)

    matches = match_strings(main,comparison_file,n_blocks = 'guess',min_similarity = minimum_similarity,max_n_matches = 1)

    return matches

# %%
def highest_score_per_image(df,labels,filenames,minimum_similarity):
    # Getting the highest score for each individual image 
    index_to_labels = df.copy()
    for a in index_to_labels.right_index.unique():
        index_to_labels.loc[index_to_labels['right_index'] == a, 'right_index'] = labels[a]
    unique_labels = index_to_labels.loc[index_to_labels.groupby('right_index')['similarity'].idxmax()]

#     print("Of the",len(filenames),"images evaluated",len(unique_labels), "have a prediction score above",minimum_similarity*100, "percent.")
    return unique_labels
# unique_labels = highest_score_per_image(ascending_df,labels,filenames,minimum_similarity)

# %%
def pooled_match(comparison_file,labels,filenames, minimum_similarity = .7,**kwargs):
    # Take in any number of files containing strings to match against and return a dictionary
    # with keys the same name as input and values as the dataframe with matching information
   
    corpus_list = []
    corpus_name = []
    
    for k,v in kwargs.items():
        # Convert to series (string-grouper requires this type), will work if input is list, array, or series
        if not isinstance(v, pd.Series):
            v = pd.Series(v)
        corpus_list.append(v)
        corpus_name.append(k)
    
    func = partial(match, comparison_file = results_series,  minimum_similarity = minimum_similarity)
    pool = multiprocessing.Pool()

    result_dic = {}
    for i,result in enumerate(pool.map(func,corpus_list)):
        result.columns.values[1] = corpus_name[i]+' Corpus'
        result.columns.values[3] = "Predictions"
        result = result.drop('left_index', axis=1)
        result = highest_score_per_image(result,labels,filenames,minimum_similarity)
        result_dic[corpus_name[i]] = result

   
    return result_dic

# %%
print(len(labels),len(filenames))
results_series = pd.Series(results)
# Out:
# 24823 976

# %%
start = time.time()
results = pooled_match(results_series,labels, filenames,minimum_similarity =.01,Taxon = taxon,Geography = g,Collector = collector)
end = time.time()
print(end-start)
# for k,v in results.items():
#     display(v)
# Out:
# 28.370580911636353

# %%
for k,v in results.items():
    display(v)

# %%
# Reorganizing the df
ascending_df = matches.sort_values(by=['similarity'],ascending=False)
pd.set_option('display.width', 150)
display(ascending_df)

# %%
def matches_above_x(df,x):
    return df.loc[df['similarity']>=.75]

# %%
above_75 = matches_above_x(unique_labels,75)
display(above_75)

# %%
# Reading in the ground truth values
gt_t = workdir+'/taxon_gt.txt'
Taxon_truth = { line.split(":")[0] : line.split(": ")[1].strip() for line in open(gt_t) }

gt_g = workdir+'/geography_gt.txt'
Geography_truth = { line.split(":")[0] : line.split(": ")[1].strip() for line in open(gt_g) }

gt_c = workdir+'/collector_gt.txt'
Collector_truth = { line.split(":")[0] : line.split(": ")[1].strip() for line in open(gt_c) }

comparison_file = {"Taxon":Taxon_truth,"Geography":Geography_truth,"Collector":Collector_truth}

# %%
# need to add in the check for other species names, quite a few would match
prediction_and_imagenumber = list(zip(unique_labels.left_Taxon, unique_labels.right_index))
count = 0
for prediction,image_number in prediction_and_imagenumber:
    try:
        image = word_log_dic[image_number]
        gt = ground_truth[image]
        if gt == prediction:
            count +=1
#             print(gt,"||",prediction,'||',image)
        else:
            print('*',gt,"||",prediction,'||',image)
    except KeyError as e:
        print("Ground Truth Not Found for:",word_log_dic[image_number])
acc = count/len(unique_labels)
print("Accuracy on Predicted:",acc)
print("Total accuracy: ",count/len(filenames))

# %%
def prRed(skk): print("\033[91m{}\033[00m" .format(skk))
    
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %%
for k,v in results.items():    
    # need to add in the check for other species names, quite a few would match
    prediction_and_imagenumber = list(zip(v[k+' Corpus'], v.right_index))
    count = 0
    print('Evaluation for',k)
    for prediction,image_number in prediction_and_imagenumber:
        try:
            image = word_log_dic[image_number]
            gt = comparison_file[k][image]
            if gt == prediction:
                count +=1
                print(gt,"||",prediction,'||',image)
            else:
                print(color.RED+gt+"||"+prediction+'||'+image+color.END)
        except KeyError as e:
            print("Ground Truth Not Found for:",word_log_dic[image_number])
    
    acc = count/len(v)
    print(color.BOLD+"Accuracy on Predicted:"+str(acc)+color.END)
    print(color.BOLD+"Total accuracy: "+str(count/len(filenames))+color.END)
    print(color.BOLD+"Total Guessed:"+str(len(prediction_and_imagenumber))+color.END)
    print('\n\n********************************\n\n')
# Out:
# Evaluation for Taxon
# Isopterygium nivescens||Chaetogastra mollis||1019531437
# Siler montanum||Lolium perenne||1019752371
# Eriophorum tenellum||Eriophorum gracile||1038924603
# Solidago patula||Acaciella angustissima||1038926232
# Nuttallanthus canadensis||Clarkia xantiana||1038933447
# Suaeda linearis || Suaeda linearis || 1038967579
# Eriogonum brachypodum||Eriogonum parvifolium||1038991156
# Chenopodium hybridum || Chenopodium hybridum || 1039025105
# Bidens cornuta || Bidens cornuta || 1055366369
# Mangifera duperreana||Poa interior||1056014429
# Calophyllum vitiense||Mercurialis annua||1056069802
# Angraecum rostratum||Tapirira obtusa||1056306307
# Calymmodon clavifer||Adiantum pedatum||1057234135
# Fumaria capreolata||Pilea pumila||1057260090
# Psydrax schimperiana || Psydrax schimperiana || 1057464806
# Cladophora columbiana||Racomitrium microcarpum||1057532849
# Cuspidaria simplicifolia||Astragalus simplicifolius||1057553687
# Frullania asagrayana||Salix nigra||1091063773
# Rhizomnium glabrescens||Rhizomnium punctatum||1091087924
# Centaurea tuntasia || Centaurea tuntasia || 1135439455
# Verbascum nigrum||Plagiomnium medium||1144111060
# Verbascum thapsus||Gratiola officinalis||1144111255
# Veronica agrestis||Carex pellita||1144111291
# Veronica serpyllifolia||Clethra alnifolia||1144113124
# Valeriana excelsa||Agrostis perennans||1144116297
# Succisa pratensis || Succisa pratensis || 1144116842
# Artocarpus rigidus||Cerinthe major||2513883147
# Artocarpus rigidus || Artocarpus rigidus || 2513883304
# Ficus ribes||Arytera litoralis||2513913908
# Chenopodium quinoa||Dryopteris intermedia||2513965497
# Aerva sanguinolenta||Dryopteris intermedia||2513966458
# Axyris amaranthoides||Dryopteris intermedia||2513976485
# Drepananthus pruniferus||Arytera litoralis||2514046501
# Friesodielsia latifolia||Ixora grandifolia||2514056183
# Litsea elliptica || Litsea elliptica || 2514086404
# Crateva magna||Cirsium muticum||2514102813
# Poterium verrucosum||Arytera litoralis||2514129946
# Hirtella americana||Arytera litoralis||2514177451
# Clausena lansium || Clausena lansium || 2514219426
# Cleidion javanicum || Cleidion javanicum || 2514242786
# Thymelaea dioica||Arytera litoralis||2514332268
# Eryngium balansae||Arytera litoralis||2514362967
# Eryngium ebracteatum||Dryopteris intermedia||2514376754
# Shorea ovalis||Bunias orientalis||2514380395
# Malvella lepidota || Malvella lepidota || 2514386394
# Abutilon theophrasti || Abutilon theophrasti || 2514398234
# Viola rupestris || Viola rupestris || 2514401720
# Ligusticum ferulaceum||Cirsium muticum||2514461919
# Vitex agnus-castus||Cladium mariscoides||2514462780
# Gynotroches axillaris || Gynotroches axillaris || 2514464378
# Bignonia aequinoctialis||Gratiola officinalis||2514481577
# Myrsine lamii || Myrsine lamii || 2514509647
# Ardisia purpurea||Myrsine lamii||2514512541
# Symplocos robinsonii || Symplocos robinsonii || 2514515297
# Gaertnera rufinervis||Psychotria costivenia||2514524961
# Vitex obovata||Ludisia discolor||2514528877
# Cyrtandra picta || Cyrtandra picta || 2514533738
# Adenosma hirsutum||Rhizomnium punctatum||2514561032
# Salvia verbenaca||Arytera litoralis||2514563201
# Lonicera acuminata || Lonicera acuminata || 2514597432
# Psychotria vogeliana||Potamogeton diversifolius||2514598419
# Verbascum nigrum||Syrrhopodon incompletus||2514607056
# Scrophularia divaricata || Scrophularia divaricata || 2514618329
# Corynephorus canescens || Corynephorus canescens || 2514666766
# Peponium vogelii||Passiflora sexflora||2514667385
# Carduus personata || Carduus personata || 2514695932
# Lolium multiflorum || Lolium multiflorum || 2514708896
# Hypericum elodes||Dryopteris intermedia||2514718776
# Oenothera biennis||Dryopteris intermedia||2514723844
# Ammophila arenaria || Ammophila arenaria || 2514761846
# Veronica scutellata||Dryopteris intermedia||2514770172
# Viola palustris||Dryopteris intermedia||2514810679
# Lepidium densiflorum||Arytera litoralis||2514847693
# Lamium maculatum||Pernettya prostrata||2514854487
# Cyrtomium fortunei||Polystichum acrostichoides||2514917088
# Picris hieracioides||Dryopteris intermedia||2514946920
# Diplazium polypodioides||Yucca baccata||2515006045
# Micrasterias furcata||Lysimachia maritima||2515134729
# Goniothalamus elmeri || Goniothalamus elmeri || 2515196651
# Philodendron sagittifolium || Philodendron sagittifolium || 2515216190
# Cerastium biebersteinii||Arytera litoralis||2515241297
# Cymbocarpa refracta||Populus alba||2515252166
# Asplenium serratum||Pedicularis procera||2515327027
# Pallenis spinosa||Chenopodium album||2515398418
# Silene physocalycina||Gratiola officinalis||3028987457
# Hieracium murorum||Garuga pinnata||3028997059
# Anastrophyllum auritum || Anastrophyllum auritum || 3029006515
# Equisetum arvense || Equisetum arvense || 3042814259
# Hemarthria compressa || Hemarthria compressa || 3043554903
# Scrophularia heterophylla || Scrophularia heterophylla || 3052190309
# Viola sheltonii || Viola sheltonii || 3053337231
# Viola adunca || Viola adunca || 3053440922
# Trifolium depauperatum||Hymenophyllum plumosum||3053442572
# Onychium siliculosum||Vitis vinifera||3060557324
# Hypericum scouleri || Hypericum scouleri || 3091199136
# Sporobolus clandestinus||Panicum clandestinum||3092906623
# Chloris virgata||Siparuna sessiliflora||3092956655
# Alloberberis trifoliolata||Berberis vulgaris||3111515383
# Erigeron bonariensis || Erigeron bonariensis || 3125034214
# Poa arctica||Groenlandia densa||3334581963
# Schizachyrium scoparium || Schizachyrium scoparium || 3340047855
# Solidago rugosa||Thalictrum simplex||3341239321
# Stellaria graminea||Stellaria media||3341248414
# Populus nigra || Populus nigra || 3341257544
# Dianthus orientalis||Tilia americana||3356432307
# Vicia americana || Vicia americana || 3356803607
# Juniperus communis||Pallenis spinosa||3356834058
# Vicia americana || Vicia americana || 3356836015
# Muhlenbergia richardsonis || Muhlenbergia richardsonis || 3357284466
# Prosthechea ochracea || Prosthechea ochracea || 3385632342
# Adenocarpus commutatus || Adenocarpus commutatus || 3392108313
# Persicaria maculosa||Polygonum erectum||3392122454
# Dianthus strictus || Dianthus strictus || 3404307303
# Astragalus physocalyx||Astragalus miser||3413669029
# Platygyrium repens||Pilosella officinarum||3416707560
# Pseudoleskea saviana || Pseudoleskea saviana || 3416740305
# Coelogyne xyrekes || Coelogyne xyrekes || 3459889344
# Syrrhopodon incompletus||Carex stricta||3467294610
# Rhizomnium punctatum||Solanum melongena||3467354375
# Crossidium squamiferum||Passiflora sexflora||3467359925
# Rhizomnium punctatum || Rhizomnium punctatum || 3467360175
# Heterotheca fastigiata||Croton californicus||3469863708
# Baptisia alba || Baptisia alba || 3469894549
# Stachys pycnantha || Stachys pycnantha || 3469909240
# Solidago fistulosa || Solidago fistulosa || 3469965760
# Sagina decumbens||Stellaria longifolia||3469982849
# Castilleja miniata || Castilleja miniata || 3470019601
# Erodium cicutarium || Erodium cicutarium || 3503204182
# Bryum capillare||Carex capillaris||3696559994
# Ilex montana || Ilex montana || 3698756098
# Chenopodium album || Chenopodium album || 3703056529
# Carex aestivalis || Carex aestivalis || 3709798405
# Clethra alnifolia || Clethra alnifolia || 3709961181
# Juncus dudleyi || Juncus dudleyi || 3734813368
# Logfia minima || Logfia minima || 436703955
# Thesium alpinum || Thesium alpinum || 436716407
# Porotrichum elongatum||Succisa pratensis||436811558
# Plagiothecium lucidum||Gentianella amarella||436830234
# Stelis ruprechtiana||Zanthoxylum leprieurii||436990042
# Lycopodiella alopecuroides||Sophora alopecuroides||437016988
# Senna multiglandulosa||Prunus tomentosa||437056001
# Myrtopsis pomaderridifolia || Myrtopsis pomaderridifolia || 437160969
# Carya tonkinensis || Carya tonkinensis || 437201612
# Cerinthe major || Cerinthe major || 437205236
# Indigofera aralensis || Indigofera aralensis || 437268052
# Pauridiantha paucinervis||Croton linearis||437308856
# Dehaasia cuneata||Berberis vulgaris||437356552
# ...
# Kievits DBJ||Licent, E.||2513603274
# Soest JL van||P. White||2513611146
# Gleason Jr HA||Licent, E.||2513614211
# Kleinhoonte A||Licent, E.||2513616378
# Unknown||Licent, E.||2513624958
# Perraudière HRT de la||Licent, E.||2513632425
# Unknown||Licent, E.||2513652595
# Missbach R || Missbach R || 2513656631
# Hens F||Licent, E.||2513686671
# Bünnemeijer W||Licent, E.||2513761556
# Unknown||Licent, E.||2513816674
# Schmidt||Licent, E.||2513842767
# Ule EHG||Wilkes Expedition||2513843663
# Elbert J || Elbert J || 2513843779
# Baenitz CG||Licent, E.||2513862848
# Lörzing JA||E. P. Killip||2513883147
# Bakhuizen van den Brink Sr RC||Licent, E.||2513883304
# Iboet||Licent, E.||2513913908
# Schultes||Licent, E.||2513965497
# Elmer ADE||Licent, E.||2513966458
# Cléonique||Licent, E.||2513976485
# King's collector G||Licent, E.||2514046501
# Elmer ADE||Licent, E.||2514056183
# Beumée JGB||Licent, E.||2514086404
# Poilane E||Poilane||2514102813
# Boom BK||Licent, E.||2514129946
# Türckheim H von||Humbert H.||2514177451
# Merrill ED||Blanc||2514219426
# Waterhouse JHL||Edward Palmer||2514242786
# Bordère H||Licent, E.||2514332268
# Hassler E||Licent, E.||2514362967
# Fiebrig K||Licent, E.||2514376754
# Vriese WH de||Thorel||2514380395
# Fisher JL||Licent, E.||2514386394
# Sintenis PEE||Licent, E.||2514398234
# Bauer||Russell J. Seibert||2514401720
# Leresche LFJR||Licent, E.||2514461919
# Meyers FS; Dinsmore JE||J. E. Dinsmore||2514462780
# Bakhuizen van den Brink Sr RC||Boom BK||2514464378
# Smith HH||Licent, E.||2514481577
# Clemens MS||Wright||2514509647
# Vanoverbergh MFJPM||Licent, E.||2514512541
# Steenis CGGJ van||Licent, E.||2514515297
# Clemens J; Clemens MS||Licent, E.||2514524961
# Bernard; Mogg AOD||Licent, E.||2514528877
# Dorgelo JD||Bakhuizen van den Brink Sr RC||2514533738
# Unknown||Licent, E.||2514561032
# Bloembergen S || Bloembergen S || 2514563201
# Bünnemeijer HAB||Licent, E.||2514597432
# Zenker GA||Licent, E.||2514598419
# Splitgerber FL||Licent, E.||2514607056
# Hohenacker RF||V. L. Cory||2514618329
# Sloff JG||Licent, E.||2514666766
# Louis JLP||S. Flowers||2514667385
# Boom BK || Boom BK || 2514695932
# Kobus JD||Licent, E.||2514708896
# Kok Ankersmit HJ || Kok Ankersmit HJ || 2514718776
# Herb Leeuw WC de||Licent, E.||2514723844
# Bolten D||Licent, E.||2514761846
# Jansen P; Wachter WH; Unio||Licent, E.||2514770172
# Wakker JH||E. P. Walker & E. Walker||2514810679
# Herb Posthumus L || Herb Posthumus L || 2514847693
# Herb Hattum HJ van||Licent, E.||2514854487
# Tsang WT||Licent, E.||2514917088
# Unknown||H. A. Gleason||2514946920
# Schiffner VF || Schiffner VF || 2515006045
# Bulnheim O||E. F. Williams||2515134729
# Ramos M||Licent, E.||2515196651
# Yuncker TG; Dawson RF; Youse HR||H. Precht||2515216190
# Cantonspark Baarn || Cantonspark Baarn || 2515241297
# Brade AC||Wright||2515252166
# Unreadable||H. Precht||2515327027
# Sipkes C || Sipkes C || 2515398418
# Brass LJ; Fly River Expedition of the American Musem of Natural History||H. Precht||2515481887
# Olden E van||D. L. Topping||2515509875
# Blumer JC||Licent, E.||2515524620
# Swart JJ||H. Precht||2515533625
# Boldingh I||Licent, E.||2515642096
# Dubois L||Licent, E.||2515661641
# Venema HJ||Lemmon Herbarium||2515744959
# Unknown||Licent, E.||2515754360
# Dinn TJ||H. D. House||2515771511
# Meer J van der||Licent, E.||2515812343
# Heldreich THH von||Licent, E.||2515816966
# Alvarez RJ||Licent, E.||2515829688
# Moll JW||Licent, E.||2515897913
# Wit HCD de||Licent, E.||2515905904
# Germain RGA||Licent, E.||2515925582
# Jeswiet J||Licent, E.||2515947653
# Meer J van der||F. Anderson||2516011819
# Bourgeau (Algeria series) E||Licent, E.||2516037063
# Schlechter FRR||Schlechter,R.||2516041985
# Buwalda P||Wright||2516118664
# Schlechter FRR||Schlechter,R.||2516133079
# Gravet PJF||Licent, E.||2516176063
# Kok Ankersmit HJ||O. Nagel||2516224982
# Sarip||Licent, E.||2516233977
# Heller AA||Licent, E.||2516266693
# Ule EHG||Licent, E.||2516271128
# Smith AC||F. Tweedy||2516337873
# Kreulen DJW||Licent, E.||2516367754
# Haviland GD||Licent, E.||2516405868
# Langhe JE de||Licent, E.||2516406700
# Kloos Jr AW||Licent, E.||2516419324
# Herb Oudemans||Licent, E.||2516437739
# Bernoulli WB||Licent, E.||2516441644
# Laurellard||Licent, E.||2516447912
# Blaas W||Licent, E.||2516458084
# Docters van Leeuwen WM||Licent, E.||2516471936
# Vulpius||Licent, E.||2516495194
# Sandwith NY; Green TH||Licent, E.||2516564502
# Goethart JWC; Jongmans WJ||Licent, E.||2516594183
# Lütjeharms WJ||E.L. Reed||2516625469
# Haviland GD||Licent, E.||2516640138
# Fan CS; Li YY||Licent, E.||2516648377
# Unknown||F.G. Meyer||2516660906
# Hoogenraad HR||Licent, E.||2516664127
# Unreadable||Licent, E.||2516684995
# Unreadable||Licent, E.||2516696767
# Bordère H||Licent, E.||2516743780
# Degener O; Nitta J||Licent, E.||2516750403
# Ooststroom SJ van || Ooststroom SJ van || 2516750642
# Sloff JG; Soest JL van||Licent, E.||2516762837
# Sande Lacoste CM van der||Licent, E.||2516807990
# Poilane E||Licent, E.||2516836918
# Unknown||J. K. Small||2516850832
# Kerr AFG||O. Nagel||2516858404
# Koorneef J||Licent, E.||2516864891
# Lambertye L de||E. P. Killip||2516970560
# Stolz AF || Stolz AF || 2517047032
# Boswezen (Surinam)||H. Precht||2517073037
# Lagerheim NG von||Jennings, O.E.||2517101413
# Howe MA||Licent, E.||2517108376
# Unknown||H. Precht||2517167632
# Ducke A||Spruce R.||2517169218
# Kjellman FR||C. A. Purpus||2517171312
# Clokey IW || Clokey IW || 2517198083
# Heldreich THH von||Lemmon Herbarium||2517240779
# Kobus JD||A. Muller||2517250185
# Tulner||C. Robinson||2517266770
# Mexia YEJ||A. H. Armstrong||2517280563
# Boldingh I||H. Precht||2517302912
# Stork AL||Licent, E.||2517375344
# Winckel WF||Deplanche, E.||2517392950
# Ducke A||J. S. Blanchet||2517468164
# Zenker GA||Licent, E.||2517498400
# Buysman M||Licent, E.||2517526453
# Hansen (Lars) L||Lemmon Herbarium||2517671288
# Brandhorst AL || Brandhorst AL || 2517838221
# Hall CJJ van||Unknown||2517843127
# Valckenier Suringar J||Licent, E.||2517885479
# Mogg AOD||Licent, E.||2517893930
# A. Muller||Callier AS; Callier R||2549483800
# J. Macoun || J. Macoun || 2549491705
# P. Hagelbarger || P. Hagelbarger || 2549492260
# V. Duran||Durand, E.||2549496787
# W. C. Cheng||Charles, M.||2549603947
# Пихтина М.||Bauer||2562055936
# Guadagno,M. || Guadagno,M. || 2562090317
# W. M. Whitfield || W. M. Whitfield || 2562899020
# B. F. Bush || B. F. Bush || 2565407235
# J. Haberer||F. C. Seymour||2565452643
# Guadagno,M.||E. F. Williams||2565969320
# A. H. Alston||M. Ramos||2571435846
# O. Andersen || O. Andersen || 2571504032
# E. Brainerd; V. B. Baird||Pringle C.G.||2572960903
# W. W. Eggleston||Pringle C.G.||2573054178
# Boorman, J.L.||C. A. Davis||2573155691
# Meinshausen, K.F.||Wright||2573161023
# Helfer J.W. || Helfer J.W. || 2573212768
# M. Morgan [?]||Lemmon Herbarium||2573258025
# Francis Ramaley||F. Wood||2573328013
# A. J. Evans||Potts G||2573330291
# Francis Ramaley || Francis Ramaley || 2573469113
# Francis Ramaley; K. Richard Johnson||A. F. Hill||2573544171
# C. F. Durant || C. F. Durant || 2573563462
# M. E. Jones||Lemmon Herbarium||2575039168
# B. Maguire & J. D. Redd||Lemmon Herbarium||2575053354
# Biltmore Herbarium || Biltmore Herbarium || 2575086103
# E. C. Leonard || E. C. Leonard || 2592238071
# P. H. Allen||Sennen||2592277723
# William H. Witte||M.A. Chrysler||2595747531
# C. F. Parker || C. F. Parker || 2595756978
# Y. W. Taam||Stanley A. Cain||2597502209
# Bianor,F.||F. Clements||2597547672
# Lortet Clémence||Gardner, Gérard||2597666444
# V. L. Cory||Lemmon Herbarium||2608673843
# R. G. Reeves || R. G. Reeves || 2608680770
# Roland Edgar Cooper, Arthur Kilpin Bulley, Roland Edgar Cooper, Arthur Kilpin Bulley||F. Wood||2610882325
# E. W. Nelson||Camfield, J.H.||2612111434
# J. Steinbach || J. Steinbach || 2612114399
# C. H. T. Townsend || C. H. T. Townsend || 2612115591
# T. Howell||S. Flowers||2625851024
# R. C. Ching||E. F. Williams||2625852862
# A. Nelson||Aven Nelson||2625873744
# A. Nelson & R. A. Nelson||Aven Nelson||2625876902
# W. McAtee||H. O'Neill||2625898343
# H. P. Chandler || H. P. Chandler || 2625904355
# E. A. McGregor || E. A. McGregor || 2643351883
# A. H. Curtiss || A. H. Curtiss || 2643353998
# Sandberg, J.H.; Leiberg, J.B.||W. Freiberg||2651317899
# Schlechter,R. || Schlechter,R. || 2805014861
# Camfield, J.H.||D. L. Topping||2830034412
# W. N. Suksdorf||Pierre, L.||2848440467
# T. H. Kearney||E. V. Ekstrand||2848499425
# G. R. Vasey||Smith AC||2848503382
# T. Tang || T. Tang || 2848506530
# A. W. Ivanov || A. W. Ivanov || 2849254057
# Berkheimer, D. || Berkheimer, D. || 2858981761
# Dreisbach, R.R. || Dreisbach, R.R. || 2859014941
# Millward, W.||F.S. Collins||2859042459
# Holmes, K.R.||R. E. Horsey||2859205685
# Jennings, O.E.; Jennings, G.K.||Jennings, O.E.||2859305213
# Jennings, O.E. || Jennings, O.E. || 2859406708
# Jennings, O.E.||[no data available]||2859424505
# S. K. Selland || S. K. Selland || 2867548082
# R. E. Fridtz||Ove Dahl||2867598821
# C.F. Baker||R. E. Schultes||2884115305
# A. Chase||Sarip||2900436116
# F. H. Knowlton||Collector unknown||2900445104
# G. B. Sudworth || G. B. Sudworth || 2900455868
# A. Eastwood || A. Eastwood || 2900461439
# Pennell, F.W. (no. 13792)||Unknown||2981274251
# Bang, M. (no. 1005)||Not evident||2981282666
# Dumanskiy||H. N. Patterson||2985561385
# Aven Nelson||C.F. Baker||2989927287
# H. Hendrikson || H. Hendrikson || 3001081883
# V. Sirgo || V. Sirgo || 3001102338
# J. Treboux || J. Treboux || 3001166637
# J. Treboux || J. Treboux || 3001176019
# E. Niclasen||Lemmon Herbarium||3001179543
# C. Robinson || C. Robinson || 3005670412
# R. Combs||Elizabeth North||3005727173
# -. Combs & Rolfs||Fulford, Margaret H.||3005750161
# H. F. Pittier||Humbert H.||3005755518
# Collector unknown||Schultes||3005768358
# A. Chase || A. Chase || 3005774322
# H. Hiir||C. L. Lundell||3016516488
# R. Wiren||E. P. Killip||3016541682
# K. Eichwald||S. Flowers||3016568853
# Joh. Mikutowicz || Joh. Mikutowicz || 3016596549
# Paul Lackschewits||Dihm||3019979401
# H. Precht||Samat||3020071550
# Kluge||John M. Holzinger||3020078501
# Kotschy,C.G.T.||E. F. Williams||3028978025
# Bornmüller,J.F.N.||M. Bourgeau||3028987457
# Sudre,H.||L. Aterido||3028997059
# Herzog,T.C.J.||Georg Roth||3029006515
# Smirnov V.I.||J. Lundequist||3042814259
# J. Nusker||Claussen||3043554903
# Halácsy,E. von||G. Firmin||3052190309
# H. and M. Dearing || H. and M. Dearing || 3053337231
# H. and M. Dearing || H. and M. Dearing || 3053440922
# W. H. Brewer || W. H. Brewer || 3053442572
# M. Ramos||Jolly, A.||3060557324
# A. Nelson; J. F. Macbride||H. E. Stork||3091199136
# D. Eyles & M. Eyles||F. G. Floyd||3092906623
# G. R. Vasey||Collector unknown||3092956655
# C. S. Sargent||Lemmon Herbarium||3111515383
# Frank F. Gander || Frank F. Gander || 3125034214
# Koch, Lange||W. Freiberg||3334581963
# E.L. Reed || E.L. Reed || 3340047855
# Unknown||Wright||3341239321
# Dana W. Fellows || Dana W. Fellows || 3341248414
# Philip Dowell; William T. Davis||T. Howell||3341257544
# Rechinger,K.H.||W. H. Witte||3356432307
# J. Lunell||T. Howell||3356803607
# D. Potter || D. Potter || 3356834058
# E. B. Payson & L. E. B. Payson||Charles, M.||3356836015
# C. F. Baker||C.F. Baker||3357284466
# O. Nagel || O. Nagel || 3385632342
# Rigo,G.||Poilane||3392108313
# F. Vincent || F. Vincent || 3392122454
# Haradjian,M.||D. L. Topping||3404307303
# Bornmüller,J.F.N.||E. F. Williams||3413669029
# Fulford, Margaret H.||Scaetta H.||3416707560
# von Handel Mazzetti, H. || von Handel Mazzetti, H. || 3416740305
# A. F. G. Kerr||A. W. Ivanov||3459889344
# H. H. Bartlett||Wilkes Expedition||3467294610
# H. Möller||Sarip||3467354375
# -. Puget || -. Puget || 3467359925
# E. C. White || E. C. White || 3467360175
# Joseph A. Ewan||G. H. Shull||3469863708
# William T. Penfound || William T. Penfound || 3469894549
# Joseph A. Ewan||Lemmon Herbarium||3469909240
# P. O. Schallert || P. O. Schallert || 3469965760
# Elizabeth North || Elizabeth North || 3469982849
# W. S. Connor || W. S. Connor || 3470019601
# F.E. Clements; E.S. Clements||Jolly, A.||3503204182
# Sharp, Aaron J.||Vieillard, E.||3696559994
# F. Anderson || F. Anderson || 3698756098
# M. L. Fernald & K. M. Wiegand H. T. Darlington||O. Andersen||3703056529
# Duncan, W||P. White||3709798405
# Pyron, J; McVaugh, R||P. White||3709961181
# N. C. Fassett||Balansa, B.||3734813368
# Blanc || Blanc || 436703955
# Desnos, V.||E. C. Leonard||436716407
# Jolly, A.||E.L. Reed||436811558
# Lindig, A. || Lindig, A. || 436830234
# Glaziou, A. || Glaziou, A. || 436990042
# Weddell, H.A. || Weddell, H.A. || 437016988
# Le Guillou, M. || Le Guillou, M. || 437056001
# Schlechter, F.R.R.||Schlechter,R.||437160969
# Lemarié||O. Hammar||437201612
# Durand, E. || Durand, E. || 437205236
# Pierre, L.||Lindig, A.||437268052
# Humbert, H.||Humbert H.||437308856
# Thorel || Thorel || 437356552
# Clemens, J. & M.S. || Clemens, J. & M.S. || 437375295
# Segret, L.||Fisher JL||437378615
# Pentland, J.B.||R. G. Reeves||437420788
# Chevalier, A.J.B.||Chevalier, A.||437448502
# Tisserant, C. || Tisserant, C. || 437492281
# Dombey, J.||Licent, E.||437498688
# Chevalier, A.J.B.||Chevalier, A.||437538294
# Huet, A.||Lemmon Herbarium||437612824
# Poilane, E.||Poilane||437638258
# Coqueray, J.||Blake, S.T.||437639743
# Burchell, W.J. || Burchell, W.J. || 437640137
# Fernald, M.L.||M. L. Fernald||437656118
# Drège, J.F.||Le Guillou, M.||437656942
# Eggers, H.F.A. von || Eggers, H.F.A. von || 437659994
# Poilane || Poilane || 437667776
# Samat||Tauscher JA||437693558
# Tulasne, M.||Koch, Lange||437804966
# Mandon, G.||A G. Bagshawe||437868891
# Claussen||F. S. Earle||437895938
# Perrier de la Bâthie, H. || Perrier de la Bâthie, H. || 437955154
# Licent, E. || Licent, E. || 437963061
# Vieillard, E.||E. F. Williams||438057885
# Chevalier, A.J.B.||Licent, E.||438118888
# Tuczkiewicz, D.||Koch, Lange||438120086
# Fries, R.E.||Wilkes Expedition||438153065
# Rodriguez, L. || Rodriguez, L. || 438202601
# Wright||M. A. Day||438211454
# Rothkegel, L.||Camus, A.||438294181
# Perrier de la Bâthie, H. || Perrier de la Bâthie, H. || 438299177
# Drushel, J.A.||C. A. Purpus||438313505
# Rochebrune|de||B. Esmark||438478181
# Rodriguez, L. || Rodriguez, L. || 438582009
# Drège, J.F.||D. L. Topping||438633225
# Hahn, L.||Cléonique||438645471
# Bunge, A.A. von|Bienert], [T.||Axel Arrhenius||438658471
# Lhote, H.||Chevalier, A.||438824413
# Glaziou, A.||F. O. Grover||438825081
# Chevalier, A. || Chevalier, A. || 438835964
# Gay, C.||Gay, H.||438902394
# Schweinfurth, G.A.||Durand, E.||438953416
# Privault, D. || Privault, D. || 438972235
# Przewalski, N.M. || Przewalski, N.M. || 438974427
# Chevalier, A.J.B.||Chevalier, A.||438985152
# Chevalier, A.J.B.||Hofmann,Hermann||438991779
# Regnell || Regnell || 439102167
# Thwaites, G.H.K.||Claussen||439241145
# Humbert, H.||Humbert H.||439286989
# Perrier de la Bâthie, H. || Perrier de la Bâthie, H. || 439294172
# Grelet, L.J.||Gay, H.||439310574
# Decary, R. || Decary, R. || 439330078
# Glaziou, A.||Tulner||439392092
# Bové||N. Pike||439392892
# Rugel||Deplanche, E.||439395736
# Morson || Morson || 439453353
# Gay, H.||T. Tang||439633342
# Boivin||Morice Vanoverbergh||462516430
# Baudouin, A. || Baudouin, A. || 474656434
# Deplanche, E. || Deplanche, E. || 474752652
# Sennen || Sennen || 474761544
# Puiggari||Licent, E.||474815805
# Balansa|Benjamin||L. Constance||474857008
# Saint-Hilaire, A. de||A. Matthies||474921033
# Schlechter, Friedrich Richard Rudolf||Schlechter,R.||575063194
# Burse (Dr.)||Jespersen K.||575124657
# Meyers, Fred S. & Dinsmore, J.E.||W. Over||575194266
# Winkler, Hans||Unknown||575233549
# Dinsmore, John Edward||J. E. Dinsmore||575349632
# Balansa, B.||Theodore Payne||607734568
# Balansa, B. || Balansa, B. || 607743206
# Fruchard||Not evident||667355588
# Letourneux, A.||A. E. Blewitt||667477358
# Guillon, A.||Axel Arrhenius||667499366
# Herzog, T.||F. J. Hermann||667740521
# Bonnardon, R. || Bonnardon, R. || 684506968
# Charles, M.||C. L. Pollard||694333780
# Prater||Buysman M||694707666
# Bourgeau, E.||N. L. Britton||731352746
# Camus, A.||Olden E van||731408891
# Gossweiler, J. || Gossweiler, J. || 813379916
# Wright,C.||Auguste Nicolas Pomel||864909330
# O. A. Hoffstad||Brass LJ; Fly River Expedition of the American Musem of Natural History||900324877
# Ducke, A.||A. Ducke||912507071
# Loscos, F.||A. S. Pease||912540960
# Deséglise, A.||Brandhorst AL||912565425
# Huet du Pavillion, A.; Huet du Pavillion, E. || Huet du Pavillion, A.; Huet du Pavillion, E. || 912570867
# Accuracy on Predicted:0.29918032786885246
# Total accuracy: 0.29918032786885246
# Total Guessed:976
#
#
# ********************************

# %%
for k,v in words_identified.items():
    print(k,v)

# %%
# CRAFT on images to get bounding boxes
images = []
corrupted_images = []
boxes = {}
count= 0
file_types = (".jpg", ".jpeg",".png")
for filename in tqdm(os.listdir(workdir)):
    if filename.endswith(file_types):
        image = workdir+'/'+filename
        try:
            img = Image.open(image) # open the image file
            img.verify() # verify that it is, in fact an image
            images.append(image)
            bounding_areas = craft.detect_text(image)
            boxes[image] = bounding_areas['boxes']
        except (IOError, SyntaxError) as e:
            corrupted_images.append(image)

            
#     count +=1
#     # Using count for time being to get things working, remove once setup is complete
#     if count == 5:
#         break

# %%
# trainset2 = datasets.ImageFolder(workdir, transform = processor)
# trainloader2 = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True)# for i, data in enumerate(trainloader):

# Checking size of all the segmentation images (about 1/6 input)
root_directory = Path(workdir)
sum(f.stat().st_size for f in root_directory.glob('**/*') if f.is_file())

def save_bounding(filename,bounding_boxes):
# function to save the boudning box outputs from CRAFT segmentation

    f = open(filneame+".pkl","wb")

    # write the python object (dict) to pickle file
    pickle.dump(bounding_boxes,f)

    # close file
    f.close()
    
def display_segmentations(boxes_dict): # Check this later if we dont want to save all the image segementations
    # Function takes in the dictionary of image_path and bounding boxes and displays all of the segmentations
    
    count = 0
    for image_path,bounding_boxes in boxes_dict.items():
        original_image = cv2.imread(image_path)
        for box in v:
            segmentation = original_image[int(box[0][1]): int(box[2][1]), 
                  int(box[0][0]): int(box[2][0])]

        segmented_image = Image.fromarray(segmentation).convert("RGB")
        display(segmented_image)
        count+=1
        if count>5:
            break

            
# Downloading the tr-ocr model and processor
# processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten") 
# model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")

# Training set creation
# trainset = datasets.ImageFolder(output_dir_craft, transform = processor)
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Put model on the gpu 
# model.to(device)

# img_dir = '/usr3/graduate/colejh/craft3/'
# for filename in os.listdir(img_dir):
#     for filename2 in os.listdir(img_dir+'/'+filename):
#         image = Image.open(img_dir+'/'+filename+'/'+filename2)
#         pixel_values = processor(image, return_tensors="pt").pixel_values 
#         generated_ids = model.generate(pixel_values)
#         generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
#         display(image)
#         print("Text: "+generated_text)

# %%
# Checking size of all the segmentation images (about 1/6 input)
root_directory = Path(workdir)
sum(f.stat().st_size for f in root_directory.glob('**/*') if f.is_file())


# saving the bounding boxes dictionary 
f = open("boundingboxes.pkl","wb")

# write the python object (dict) to pickle file
pickle.dump(dict,f)

# close file
f.close()

#Check this later if we dont want to save all the image segementations
count = 0
for k,v in boxes.items():
    full_image = cv2.imread(k)
    for box in v:
        segmentation = full_image[int(box[0][1]): int(box[2][1]), 
              int(box[0][0]): int(box[2][0])]
    
    #Drop this later, just for checking stuff
    image = Image.fromarray(segmentation).convert("RGB")
    display(image)
   
    count+=1
    if count>5:
        break
