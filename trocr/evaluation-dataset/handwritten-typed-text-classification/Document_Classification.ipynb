# %%
import os
import shutil
from collections import defaultdict
from tqdm import tqdm
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torchvision.transforms import transforms
from torchvision.transforms.functional import pad

from utils.utils import *
from craft_text_detector import Craft

from transformers import (TrOCRProcessor, 
                        TrOCRForCausalLM, 
                        VisionEncoderDecoderModel)

# %%
# --in-dir
# --out-dir
# --model-path

# %%
workdir = "/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/TROCR_Training/goodfiles/"
output_dir_craft = "data/Doc_Classification/input"

# initialize the CRAFT model
craft = Craft(output_dir = output_dir_craft, 
              export_extra = False, 
              text_threshold = .7, 
              link_threshold = .4, 
              crop_type="poly", 
              low_text = .3, 
              cuda = True)

# CRAFT on images to get bounding boxes
images = []
corrupted_images = []
no_segmentations = []
boxes = {}
count= 0
img_name = []
box = []
file_types = (".jpg", ".jpeg",".png")
    
for filename in tqdm(sorted(os.listdir(workdir))):
    if filename.endswith(file_types):
        image = workdir+filename
        try:
            img = Image.open(image) 
            img.verify() # Check that the image is valid
            bounding_areas = craft.detect_text(image)
            if len(bounding_areas['boxes']): #check that a segmentation was found
                images.append(image)
                boxes[image] = bounding_areas['boxes']
                
            else:
                no_segmentations.append(image)
        except (IOError, SyntaxError) as e:
            corrupted_images.append(image)

# %%
# preprocess = transforms.Compose([
#     transforms.Resize([100, ]),
#     transforms.Lambda(
#         lambda img: pad(img, padding=(0, 0, max(0, 200 - img.width), max(0, 100 - img.height)), 
#                                               fill=(255, 255, 255))),
#     transforms.CenterCrop((100, 200)),
#     PartialErosion(iterations=2),
#     transforms.ToTensor(),
#     transforms.Grayscale(num_output_channels=3),
#     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
# ])

# %%
# Move the model to the device (CPU or GPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
# # vgg_from_scratch_w_erosion_v2.pth

# best_model = models.densenet121(weights="DenseNet121_Weights.IMAGENET1K_V1")
# # Modify the model for binary classification
# num_ftrs = best_model.classifier.in_features
# best_model.classifier = nn.Linear(num_ftrs, 1)

# # best_model = VGG16Binary(input_shape=(3, 100, 200), num_classes=1)  # Create an instance of the model

# best_model.load_state_dict(torch.load('model/densenet_10_5_layers_unlocked.pth'))
# best_model = best_model.to(device)

processor = TrOCRProcessor.from_pretrained('microsoft/trocr-large-stage1')
model = VisionEncoderDecoderModel.from_pretrained('microsoft/trocr-large-stage1')

# Freeze TrOCR layers
for param in model.parameters():
    param.requires_grad = False

# Define our classifier
classifier = nn.Sequential(
    
    nn.Conv2d(1, 16, kernel_size=1, stride=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, 2),
    nn.Conv2d(16, 32, kernel_size=1, stride=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, 2),
    nn.Conv2d(32, 32, kernel_size=1, stride=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, 2),
    nn.Flatten(),
    nn.Linear(32 * (577 // 8) * (1024 // 8), 512),
    nn.ReLU(inplace=True),
    nn.Linear(512, 512),
    nn.ReLU(inplace=True),
    nn.Dropout(0.2),
    nn.Linear(512, 256),
    nn.ReLU(inplace=True),
    nn.Linear(256, 1)
)
# Out:
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-large-stage1 and are newly initialized: ['encoder.pooler.dense.weight', 'encoder.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
classifier = torch.nn.DataParallel(classifier, [0]) # list(range(torch.cuda.device_count()))
classifier.load_state_dict(torch.load("model/TrOCR_L_enc_feature_extraction_w_classifier.pth"))
# Out:
# <All keys matched successfully>

# %%
model.to(device)
classifier.to(device)
# Out:
# DataParallel(
#   (module): DataParallel(
#     (module): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (9): Flatten(start_dim=1, end_dim=-1)
#       (10): Linear(in_features=294912, out_features=512, bias=True)
#       (11): ReLU(inplace=True)
#       (12): Linear(in_features=512, out_features=512, bias=True)
#       (13): ReLU(inplace=True)
#       (14): Dropout(p=0.2, inplace=False)
#       (15): Linear(in_features=512, out_features=256, bias=True)
#       (16): ReLU(inplace=True)
#       (17): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
score_sum_dict = defaultdict(lambda: [0, 0]) # file_name: (hw_confidence, typed_confidence)
score_len_dict = defaultdict(lambda: [0, 0]) # file_name: (hw_count, typed_count)

# %%
craft_output_dir = "/projectnb/sparkgrp/kabilanm/goodfilescraft/"

for dir_ in os.listdir(craft_output_dir):
    for file in os.listdir(os.path.join(craft_output_dir, dir_)):
        
        key = dir_.split("_")[0]
        
        img = Image.open(craft_output_dir+dir_+"/"+file)
        
        pixel_values = processor(images=img, return_tensors="pt").pixel_values.to(device)
        encoder_outputs = model.encoder(pixel_values)
        
        image_representation = encoder_outputs.last_hidden_state

        classifier.eval()
        with torch.no_grad():
            classifier_output = classifier(image_representation.unsqueeze(1))
            
            pred_confidence = torch.sigmoid(classifier_output)
            predicted = torch.round(pred_confidence)
            
            if(predicted == 0):
                score_sum_dict[key][0] += 1-pred_confidence
                score_len_dict[key][0] += 1
            if(predicted == 1):
                score_sum_dict[key][1] += pred_confidence
                score_len_dict[key][1] += 1

# %%
score_sum_dict = dict(score_sum_dict)
score_len_dict = dict(score_len_dict)

# %%
score_avg_dict = defaultdict(lambda: [0, 0])

# %%
hw_score, typed_score = 0, 0

for sum_, len_ in zip(score_sum_dict.items(), score_len_dict.items()):
    if(len_[1][0] == 0):
        hw_score = 0
    elif(len_[1][1] == 0):
        typed_score = 0
    else:
        hw_score = sum_[1][0]/len_[1][0]
        typed_score = sum_[1][1]/len_[1][1]
    score_avg_dict[sum_[0]] = [hw_score, typed_score]

# %%
score_avg_dict = dict(score_avg_dict)
score_avg_dict
# Out:
# {'2452230713': [tensor([[0.9621]], device='cuda:0'),
#   tensor([[0.8421]], device='cuda:0')],
#  '2900445104': [tensor([[0.9422]], device='cuda:0'),
#   tensor([[0.8795]], device='cuda:0')],
#  '2575039168': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.8792]], device='cuda:0')],
#  '2236018163': [tensor([[0.9824]], device='cuda:0'),
#   tensor([[0.9793]], device='cuda:0')],
#  '2235956175': [tensor([[0.9052]], device='cuda:0'),
#   tensor([[0.9870]], device='cuda:0')],
#  '2426921679': [tensor([[0.8984]], device='cuda:0'),
#   tensor([[0.9489]], device='cuda:0')],
#  '2859042459': [tensor([[0.8701]], device='cuda:0'),
#   tensor([[0.9536]], device='cuda:0')],
#  '1563240212': [tensor([[0.9861]], device='cuda:0'),
#   tensor([[0.9476]], device='cuda:0')],
#  '3467354375': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9131]], device='cuda:0')],
#  '1998387136': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9457]], device='cuda:0')],
#  '2265485412': [tensor([[0.9993]], device='cuda:0'),
#   tensor([[0.9157]], device='cuda:0')],
#  '1998758107': [tensor([[0.9992]], device='cuda:0'),
#   tensor([[0.9084]], device='cuda:0')],
#  '2848506530': [tensor([[0.9994]], device='cuda:0'),
#   tensor([[0.9706]], device='cuda:0')],
#  '3356803607': [tensor([[0.9996]], device='cuda:0'),
#   tensor([[0.9754]], device='cuda:0')],
#  '3341248414': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9666]], device='cuda:0')],
#  '2595747531': [tensor([[0.9687]], device='cuda:0'),
#   tensor([[0.9992]], device='cuda:0')],
#  '1322253698': [tensor([[0.9999]], device='cuda:0'),
#   tensor([[0.9997]], device='cuda:0')],
#  '1802596511': [tensor([[0.8476]], device='cuda:0'),
#   tensor([[0.9234]], device='cuda:0')],
#  '2575053354': [0, tensor([[0.9234]], device='cuda:0')],
#  '1998387245': [tensor([[0.9987]], device='cuda:0'),
#   tensor([[0.8759]], device='cuda:0')],
#  '3356834058': [tensor([[0.9868]], device='cuda:0'),
#   tensor([[0.9412]], device='cuda:0')],
#  '1320460457': [tensor([[0.9900]], device='cuda:0'),
#   tensor([[1.]], device='cuda:0')],
#  '3341239321': [tensor([[0.9566]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '2012884607': [tensor([[0.8793]], device='cuda:0'),
#   tensor([[0.8216]], device='cuda:0')],
#  '2236950433': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.9326]], device='cuda:0')],
#  '2571504032': [tensor([[0.8692]], device='cuda:0'),
#   tensor([[0.8516]], device='cuda:0')],
#  '1928276301': [tensor([[0.9824]], device='cuda:0'),
#   tensor([[0.9521]], device='cuda:0')],
#  '2284154890': [tensor([[0.7281]], device='cuda:0'),
#   tensor([[0.9460]], device='cuda:0')],
#  '2452246731': [tensor([[0.9967]], device='cuda:0'),
#   tensor([[0.9402]], device='cuda:0')],
#  '1456276626': [tensor([[0.9687]], device='cuda:0'),
#   tensor([[0.8822]], device='cuda:0')],
#  '2848503382': [tensor([[0.9427]], device='cuda:0'),
#   tensor([[1.]], device='cuda:0')],
#  '2452262576': [tensor([[0.8333]], device='cuda:0'),
#   tensor([[0.9319]], device='cuda:0')],
#  '2625873744': [tensor([[0.9353]], device='cuda:0'),
#   tensor([[0.9380]], device='cuda:0')],
#  '2643351883': [tensor([[0.8318]], device='cuda:0'),
#   tensor([[0.7764]], device='cuda:0')],
#  '1927799942': [tensor([[0.9976]], device='cuda:0'),
#   tensor([[0.9674]], device='cuda:0')],
#  '1456008930': [tensor([[0.9329]], device='cuda:0'),
#   tensor([[0.8874]], device='cuda:0')],
#  '2425435971': [0, tensor([[0.8874]], device='cuda:0')],
#  '1802552799': [tensor([[0.9639]], device='cuda:0'),
#   tensor([[0.9654]], device='cuda:0')],
#  '1999283271': [tensor([[0.7964]], device='cuda:0'),
#   tensor([[0.9380]], device='cuda:0')],
#  '1928034398': [tensor([[0.9996]], device='cuda:0'),
#   tensor([[0.9899]], device='cuda:0')],
#  '2900455868': [tensor([[0.9257]], device='cuda:0'),
#   tensor([[1.]], device='cuda:0')],
#  '2625852862': [tensor([[0.9626]], device='cuda:0'),
#   tensor([[0.8909]], device='cuda:0')],
#  '2900461439': [tensor([[0.9695]], device='cuda:0'),
#   tensor([[0.9141]], device='cuda:0')],
#  '2284326054': [tensor([[0.9171]], device='cuda:0'),
#   tensor([[0.9032]], device='cuda:0')],
#  '2608680770': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.9571]], device='cuda:0')],
#  '2859305213': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[1.]], device='cuda:0')],
#  '2452293722': [tensor([[0.9124]], device='cuda:0'),
#   tensor([[0.9710]], device='cuda:0')],
#  '1998994775': [tensor([[0.9867]], device='cuda:0'),
#   tensor([[0.9130]], device='cuda:0')],
#  '2426917844': [tensor([[0.9785]], device='cuda:0'),
#   tensor([[0.9580]], device='cuda:0')],
#  '1999028044': [tensor([[0.9765]], device='cuda:0'),
#   tensor([[0.9538]], device='cuda:0')],
#  '1426171668': [tensor([[0.9523]], device='cuda:0'),
#   tensor([[0.9815]], device='cuda:0')],
#  '1702851818': [tensor([[0.9885]], device='cuda:0'),
#   tensor([[0.9349]], device='cuda:0')],
#  '2595756978': [tensor([[0.9292]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '1318797445': [tensor([[0.9804]], device='cuda:0'),
#   tensor([[0.9403]], device='cuda:0')],
#  '1998370401': [tensor([[0.9997]], device='cuda:0'),
#   tensor([[0.9943]], device='cuda:0')],
#  '1998333126': [tensor([[0.9825]], device='cuda:0'),
#   tensor([[0.9564]], device='cuda:0')],
#  '2236116492': [tensor([[0.9037]], device='cuda:0'),
#   tensor([[0.9834]], device='cuda:0')],
#  '1930277693': [tensor([[0.9127]], device='cuda:0'),
#   tensor([[0.9048]], device='cuda:0')],
#  '3111515383': [tensor([[0.8656]], device='cuda:0'),
#   tensor([[0.9378]], device='cuda:0')],
#  '2512789170': [tensor([[0.9959]], device='cuda:0'),
#   tensor([[0.8643]], device='cuda:0')],
#  '2284285249': [tensor([[0.9446]], device='cuda:0'),
#   tensor([[0.8962]], device='cuda:0')],
#  '2265509546': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.9430]], device='cuda:0')],
#  '1426052966': [tensor([[0.9972]], device='cuda:0'),
#   tensor([[0.9755]], device='cuda:0')],
#  '1999130856': [tensor([[0.8872]], device='cuda:0'),
#   tensor([[0.9636]], device='cuda:0')],
#  '1998611243': [tensor([[0.9993]], device='cuda:0'),
#   tensor([[0.7843]], device='cuda:0')],
#  '2425414867': [tensor([[0.9999]], device='cuda:0'),
#   tensor([[0.8545]], device='cuda:0')],
#  '1998969928': [tensor([[0.9182]], device='cuda:0'),
#   tensor([[0.8709]], device='cuda:0')],
#  '1998540182': [tensor([[0.9928]], device='cuda:0'),
#   tensor([[0.9990]], device='cuda:0')],
#  '2565452643': [tensor([[0.9763]], device='cuda:0'),
#   tensor([[0.9690]], device='cuda:0')],
#  '2573054178': [tensor([[0.9757]], device='cuda:0'),
#   tensor([[0.9405]], device='cuda:0')],
#  '1998836464': [tensor([[0.9720]], device='cuda:0'),
#   tensor([[0.9227]], device='cuda:0')],
#  '2397800089': [tensor([[0.9990]], device='cuda:0'),
#   tensor([[0.8909]], device='cuda:0')],
#  '2859014941': [tensor([[0.9892]], device='cuda:0'),
#   tensor([[0.9398]], device='cuda:0')],
#  '1999047345': [tensor([[0.9890]], device='cuda:0'),
#   tensor([[0.9035]], device='cuda:0')],
#  '1319864119': [tensor([[0.9892]], device='cuda:0'),
#   tensor([[0.9205]], device='cuda:0')],
#  '1676047656': [tensor([[0.9389]], device='cuda:0'),
#   tensor([[1.]], device='cuda:0')],
#  '1317726996': [tensor([[0.9457]], device='cuda:0'),
#   tensor([[0.9976]], device='cuda:0')],
#  '1455174725': [tensor([[0.9990]], device='cuda:0'),
#   tensor([[0.9446]], device='cuda:0')],
#  '3459889344': [tensor([[0.9947]], device='cuda:0'),
#   tensor([[0.9149]], device='cuda:0')],
#  '2549483800': [tensor([[0.9882]], device='cuda:0'),
#   tensor([[0.9638]], device='cuda:0')],
#  '1999314245': [tensor([[0.9966]], device='cuda:0'),
#   tensor([[0.9565]], device='cuda:0')],
#  '1998543749': [tensor([[0.9998]], device='cuda:0'),
#   tensor([[0.9258]], device='cuda:0')],
#  '1928246346': [tensor([[0.8794]], device='cuda:0'),
#   tensor([[0.9802]], device='cuda:0')],
#  '1318373170': [tensor([[0.9339]], device='cuda:0'),
#   tensor([[0.9352]], device='cuda:0')],
#  '1929084979': [tensor([[0.8395]], device='cuda:0'),
#   tensor([[0.9857]], device='cuda:0')],
#  '3005768358': [tensor([[0.9994]], device='cuda:0'),
#   tensor([[0.8912]], device='cuda:0')],
#  '1322958063': [tensor([[0.9446]], device='cuda:0'),
#   tensor([[0.8312]], device='cuda:0')],
#  '2235995189': [tensor([[0.9968]], device='cuda:0'),
#   tensor([[0.9835]], device='cuda:0')],
#  '1318526260': [tensor([[0.9879]], device='cuda:0'),
#   tensor([[0.9336]], device='cuda:0')],
#  '1998308840': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9456]], device='cuda:0')],
#  '2265588715': [tensor([[0.9583]], device='cuda:0'),
#   tensor([[0.9284]], device='cuda:0')],
#  '2012879889': [tensor([[0.8876]], device='cuda:0'),
#   tensor([[0.9457]], device='cuda:0')],
#  '2446828060': [tensor([[0.9999]], device='cuda:0'),
#   tensor([[0.9412]], device='cuda:0')],
#  '1317746297': [tensor([[0.9051]], device='cuda:0'),
#   tensor([[0.9690]], device='cuda:0')],
#  '1319210580': [tensor([[0.9733]], device='cuda:0'),
#   tensor([[0.8821]], device='cuda:0')],
#  '1998818359': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9599]], device='cuda:0')],
#  '2284193310': [tensor([[0.9985]], device='cuda:0'),
#   tensor([[0.8759]], device='cuda:0')],
#  '1998843424': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9997]], device='cuda:0')],
#  '2235813242': [tensor([[0.9985]], device='cuda:0'),
#   tensor([[0.9997]], device='cuda:0')],
#  '1320398138': [tensor([[0.9722]], device='cuda:0'),
#   tensor([[0.9918]], device='cuda:0')],
#  '1931124118': [tensor([[0.9325]], device='cuda:0'),
#   tensor([[0.9737]], device='cuda:0')],
#  '3005750161': [tensor([[0.9515]], device='cuda:0'),
#   tensor([[0.9131]], device='cuda:0')],
#  '2900436116': [tensor([[0.9919]], device='cuda:0'),
#   tensor([[0.8911]], device='cuda:0')],
#  '1317278320': [tensor([[0.9937]], device='cuda:0'),
#   tensor([[0.8675]], device='cuda:0')],
#  '1318182025': [tensor([[0.9231]], device='cuda:0'),
#   tensor([[0.9457]], device='cuda:0')],
#  '2236176339': [tensor([[0.9168]], device='cuda:0'),
#   tensor([[0.9509]], device='cuda:0')],
#  '2284359495': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9840]], device='cuda:0')],
#  '2848499425': [tensor([[0.9935]], device='cuda:0'),
#   tensor([[0.9064]], device='cuda:0')],
#  '1929709919': [tensor([[0.9618]], device='cuda:0'),
#   tensor([[0.9760]], device='cuda:0')],
#  '1998550976': [tensor([[0.9848]], device='cuda:0'),
#   tensor([[0.9461]], device='cuda:0')],
#  '1318027385': [tensor([[0.9724]], device='cuda:0'),
#   tensor([[0.9566]], device='cuda:0')],
#  '1212567865': [tensor([[0.9574]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '3005670412': [tensor([[0.9931]], device='cuda:0'),
#   tensor([[0.9405]], device='cuda:0')],
#  '2426902656': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.9157]], device='cuda:0')],
#  '1998590947': [tensor([[0.9884]], device='cuda:0'),
#   tensor([[0.9457]], device='cuda:0')],
#  '1998808952': [tensor([[0.8605]], device='cuda:0'),
#   tensor([[0.8792]], device='cuda:0')],
#  '2265566552': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9688]], device='cuda:0')],
#  '3092956655': [tensor([[0.9951]], device='cuda:0'),
#   tensor([[0.8137]], device='cuda:0')],
#  '1999253468': [tensor([[0.9982]], device='cuda:0'),
#   tensor([[0.9993]], device='cuda:0')],
#  '2575086103': [tensor([[0.8703]], device='cuda:0'),
#   tensor([[0.9425]], device='cuda:0')],
#  '1998497875': [tensor([[0.9996]], device='cuda:0'),
#   tensor([[0.9836]], device='cuda:0')],
#  '1999032409': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9999]], device='cuda:0')],
#  '2284189808': [tensor([[0.9633]], device='cuda:0'),
#   tensor([[0.9858]], device='cuda:0')],
#  '2625851024': [tensor([[0.8316]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '3357284466': [tensor([[0.9532]], device='cuda:0'),
#   tensor([[0.9915]], device='cuda:0')],
#  '1998465329': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9625]], device='cuda:0')],
#  '437160969': [tensor([[0.9998]], device='cuda:0'),
#   tensor([[0.9457]], device='cuda:0')],
#  '2234232983': [tensor([[0.9987]], device='cuda:0'),
#   tensor([[0.9559]], device='cuda:0')],
#  '1702827727': [tensor([[0.9535]], device='cuda:0'),
#   tensor([[0.9025]], device='cuda:0')],
#  '2284153322': [tensor([[0.9672]], device='cuda:0'),
#   tensor([[0.9584]], device='cuda:0')],
#  '2549491705': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9638]], device='cuda:0')],
#  '1990825865': [tensor([[0.5632]], device='cuda:0'),
#   tensor([[0.9451]], device='cuda:0')],
#  '1999330570': [tensor([[0.9995]], device='cuda:0'),
#   tensor([[0.9541]], device='cuda:0')],
#  '2397779786': [tensor([[0.8928]], device='cuda:0'),
#   tensor([[0.8370]], device='cuda:0')],
#  '2236147388': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.8935]], device='cuda:0')],
#  '2284150251': [tensor([[0.9738]], device='cuda:0'),
#   tensor([[0.9449]], device='cuda:0')],
#  '1843567618': [tensor([[0.8647]], device='cuda:0'),
#   tensor([[0.8872]], device='cuda:0')],
#  '1998358368': [tensor([[0.9403]], device='cuda:0'),
#   tensor([[0.9533]], device='cuda:0')],
#  '2608673843': [0, tensor([[0.9533]], device='cuda:0')],
#  '2425404585': [tensor([[0.9965]], device='cuda:0'),
#   tensor([[0.9508]], device='cuda:0')],
#  '1456376042': [tensor([[0.9997]], device='cuda:0'),
#   tensor([[0.9559]], device='cuda:0')],
#  '2592238071': [tensor([[0.9661]], device='cuda:0'),
#   tensor([[0.9162]], device='cuda:0')],
#  '1929881359': [tensor([[0.9961]], device='cuda:0'),
#   tensor([[0.9276]], device='cuda:0')],
#  '1929883118': [0, tensor([[0.9276]], device='cuda:0')],
#  '1998968996': [tensor([[0.9546]], device='cuda:0'),
#   tensor([[0.9954]], device='cuda:0')],
#  '2848440467': [tensor([[0.9418]], device='cuda:0'),
#   tensor([[0.8552]], device='cuda:0')],
#  '1318293083': [tensor([[0.9627]], device='cuda:0'),
#   tensor([[0.9323]], device='cuda:0')],
#  '2565407235': [tensor([[0.9028]], device='cuda:0'),
#   tensor([[0.9979]], device='cuda:0')],
#  '1318334082': [tensor([[0.9113]], device='cuda:0'),
#   tensor([[0.9370]], device='cuda:0')],
#  '1999143240': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.9456]], device='cuda:0')],
#  '3043554903': [tensor([[0.9944]], device='cuda:0'),
#   tensor([[0.8517]], device='cuda:0')],
#  '2446828826': [tensor([[0.9531]], device='cuda:0'),
#   tensor([[0.9209]], device='cuda:0')],
#  '1998467065': [tensor([[0.9804]], device='cuda:0'),
#   tensor([[0.9380]], device='cuda:0')],
#  '2236597761': [tensor([[0.9326]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '3385632342': [tensor([[0.9925]], device='cuda:0'),
#   tensor([[0.9771]], device='cuda:0')],
#  '1990809725': [tensor([[0.8467]], device='cuda:0'),
#   tensor([[0.9710]], device='cuda:0')],
#  '1675940934': [tensor([[0.9964]], device='cuda:0'),
#   tensor([[0.9069]], device='cuda:0')],
#  '2235847388': [tensor([[0.9670]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '3734813368': [tensor([[0.9586]], device='cuda:0'),
#   tensor([[0.9819]], device='cuda:0')],
#  '2235866543': [tensor([[0.9595]], device='cuda:0'),
#   tensor([[0.8914]], device='cuda:0')],
#  '3392122454': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.9922]], device='cuda:0')],
#  '1321992876': [tensor([[0.9109]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '2549496787': [tensor([[0.9281]], device='cuda:0'),
#   tensor([[0.9737]], device='cuda:0')],
#  '1999217275': [0, tensor([[0.9737]], device='cuda:0')],
#  '1455960532': [0, tensor([[0.9737]], device='cuda:0')],
#  '2235750047': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[1.]], device='cuda:0')],
#  '2592277723': [tensor([[0.9614]], device='cuda:0'),
#   tensor([[0.9060]], device='cuda:0')],
#  '1321746477': [tensor([[0.9721]], device='cuda:0'),
#   tensor([[0.9999]], device='cuda:0')],
#  '1998956483': [0, tensor([[0.9999]], device='cuda:0')],
#  '2446819762': [tensor([[0.9513]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '2859205685': [tensor([[0.9720]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '2549492260': [tensor([[0.9391]], device='cuda:0'),
#   tensor([[0.9514]], device='cuda:0')],
#  '1998882868': [tensor([[0.9988]], device='cuda:0'),
#   tensor([[0.9386]], device='cuda:0')],
#  '1999401722': [tensor([[0.9406]], device='cuda:0'),
#   tensor([[0.9618]], device='cuda:0')],
#  '2512759946': [tensor([[0.9907]], device='cuda:0'),
#   tensor([[0.9440]], device='cuda:0')],
#  '1852124166': [tensor([[0.9219]], device='cuda:0'),
#   tensor([[0.9745]], device='cuda:0')],
#  '2549603947': [tensor([[0.9985]], device='cuda:0'),
#   tensor([[0.9371]], device='cuda:0')],
#  '3092906623': [tensor([[0.9840]], device='cuda:0'),
#   tensor([[0.9210]], device='cuda:0')],
#  '2625898343': [tensor([[0.9987]], device='cuda:0'),
#   tensor([[0.9378]], device='cuda:0')],
#  '1998322454': [tensor([[0.9997]], device='cuda:0'),
#   tensor([[0.9979]], device='cuda:0')],
#  '2235965636': [tensor([[0.9628]], device='cuda:0'),
#   tensor([[0.9205]], device='cuda:0')],
#  '2625876902': [tensor([[0.9965]], device='cuda:0'),
#   tensor([[0.9758]], device='cuda:0')],
#  '1318345053': [tensor([[0.9943]], device='cuda:0'),
#   tensor([[0.9132]], device='cuda:0')],
#  '3005755518': [tensor([[0.9979]], device='cuda:0'),
#   tensor([[0.9389]], device='cuda:0')],
#  '2425445076': [tensor([[0.9104]], device='cuda:0'),
#   tensor([[0.9378]], device='cuda:0')],
#  '1998394637': [0, tensor([[0.9378]], device='cuda:0')],
#  '1999262308': [tensor([[0.9921]], device='cuda:0'),
#   tensor([[0.9660]], device='cuda:0')],
#  '3005774322': [tensor([[0.9997]], device='cuda:0'),
#   tensor([[0.8714]], device='cuda:0')],
#  '2236031445': [tensor([[0.9081]], device='cuda:0'),
#   tensor([[1.]], device='cuda:0')],
#  '2643353998': [tensor([[0.9843]], device='cuda:0'),
#   tensor([[0.9315]], device='cuda:0')],
#  '1317840733': [tensor([[0.9990]], device='cuda:0'),
#   tensor([[0.9332]], device='cuda:0')],
#  '1456250583': [tensor([[0.9392]], device='cuda:0'),
#   tensor([[0.9110]], device='cuda:0')],
#  '1319326174': [tensor([[0.9937]], device='cuda:0'),
#   tensor([[0.9118]], device='cuda:0')],
#  '1999105588': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9077]], device='cuda:0')],
#  '1998980522': [tensor([[0.8969]], device='cuda:0'),
#   tensor([[0.9193]], device='cuda:0')],
#  '1999167579': [tensor([[0.9998]], device='cuda:0'),
#   tensor([[0.9781]], device='cuda:0')],
#  '2452236904': [tensor([[0.9639]], device='cuda:0'),
#   tensor([[0.9396]], device='cuda:0')],
#  '2512820352': [tensor([[0.9905]], device='cuda:0'),
#   tensor([[0.9899]], device='cuda:0')],
#  '1999413720': [tensor([[0.9979]], device='cuda:0'),
#   tensor([[0.9472]], device='cuda:0')],
#  '2625904355': [tensor([[0.9267]], device='cuda:0'),
#   tensor([[0.8815]], device='cuda:0')],
#  '2512801142': [tensor([[0.9751]], device='cuda:0'),
#   tensor([[0.9182]], device='cuda:0')],
#  '1998543588': [tensor([[0.9991]], device='cuda:0'),
#   tensor([[0.9960]], device='cuda:0')],
#  '2235755905': [tensor([[0.9809]], device='cuda:0'),
#   tensor([[0.9342]], device='cuda:0')],
#  '1998686142': [tensor([[0.9794]], device='cuda:0'),
#   tensor([[0.9905]], device='cuda:0')],
#  '1320488541': [0, tensor([[0.9905]], device='cuda:0')],
#  '2425437928': [tensor([[0.9944]], device='cuda:0'),
#   tensor([[0.9821]], device='cuda:0')],
#  '1998729261': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9773]], device='cuda:0')],
#  '2397721138': [tensor([[0.9105]], device='cuda:0'),
#   tensor([[0.9644]], device='cuda:0')],
#  '1322099762': [tensor([[0.9999]], device='cuda:0'),
#   tensor([[0.9985]], device='cuda:0')],
#  '2512761763': [tensor([[0.9927]], device='cuda:0'),
#   tensor([[0.9289]], device='cuda:0')],
#  '1318393575': [tensor([[0.9877]], device='cuda:0'),
#   tensor([[0.9864]], device='cuda:0')],
#  '1999110359': [tensor([[1.]], device='cuda:0'),
#   tensor([[0.8950]], device='cuda:0')],
#  '1999154508': [tensor([[0.9998]], device='cuda:0'),
#   tensor([[0.9843]], device='cuda:0')],
#  '1318212360': [tensor([[0.9389]], device='cuda:0'),
#   tensor([[0.8734]], device='cuda:0')],
#  '1998646322': [tensor([[0.6392]], device='cuda:0'),
#   tensor([[0.9414]], device='cuda:0')],
#  '2512855384': [tensor([[0.9556]], device='cuda:0'),
#   tensor([[0.8979]], device='cuda:0')],
#  '2858981761': [tensor([[0.9670]], device='cuda:0'),
#   tensor([[0.9276]], device='cuda:0')],
#  '2284257102': [tensor([[0.9741]], device='cuda:0'),
#   tensor([[0.8452]], device='cuda:0')],
#  '2236024256': [tensor([[0.9930]], device='cuda:0'),
#   tensor([[0.9690]], device='cuda:0')],
#  '2512764119': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9583]], device='cuda:0')],
#  '1998481102': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9605]], device='cuda:0')],
#  '2236057326': [tensor([[0.9953]], device='cuda:0'),
#   tensor([[0.9510]], device='cuda:0')],
#  '1999056693': [tensor([[0.9989]], device='cuda:0'),
#   tensor([[0.9875]], device='cuda:0')],
#  '1852143901': [tensor([[0.9818]], device='cuda:0'),
#   tensor([[0.9110]], device='cuda:0')],
#  '1320104750': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9543]], device='cuda:0')],
#  '1426166249': [tensor([[0.9996]], device='cuda:0'),
#   tensor([[0.9638]], device='cuda:0')],
#  '1999410499': [tensor([[0.8870]], device='cuda:0'),
#   tensor([[0.9757]], device='cuda:0')],
#  '1322630109': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9346]], device='cuda:0')],
#  '2235846679': [tensor([[0.9964]], device='cuda:0'),
#   tensor([[0.9830]], device='cuda:0')],
#  '3005727173': [tensor([[0.9519]], device='cuda:0'),
#   tensor([[0.8664]], device='cuda:0')],
#  '1930449245': [tensor([[0.9983]], device='cuda:0'),
#   tensor([[0.9638]], device='cuda:0')],
#  '3341257544': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9897]], device='cuda:0')],
#  '1998565761': [tensor([[0.9453]], device='cuda:0'),
#   tensor([[0.9630]], device='cuda:0')],
#  '1999317509': [tensor([[0.9810]], device='cuda:0'),
#   tensor([[0.9789]], device='cuda:0')],
#  '2452332496': [tensor([[0.9406]], device='cuda:0'),
#   tensor([[0.8998]], device='cuda:0')],
#  '1928479020': [tensor([[0.9506]], device='cuda:0'),
#   tensor([[0.9521]], device='cuda:0')],
#  '2571435846': [tensor([[0.9991]], device='cuda:0'),
#   tensor([[0.9782]], device='cuda:0')],
#  '3703056529': [tensor([[0.9962]], device='cuda:0'),
#   tensor([[0.9589]], device='cuda:0')],
#  '2512804326': [tensor([[0.9984]], device='cuda:0'),
#   tensor([[0.9689]], device='cuda:0')],
#  '2397724211': [tensor([[0.9327]], device='cuda:0'),
#   tensor([[0.7991]], device='cuda:0')],
#  '1928370989': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9296]], device='cuda:0')],
#  '1563299852': [tensor([[0.9558]], device='cuda:0'),
#   tensor([[0.9186]], device='cuda:0')],
#  '3356836015': [tensor([[0.8822]], device='cuda:0'),
#   tensor([[0.9086]], device='cuda:0')],
#  '2426886454': [tensor([[0.9697]], device='cuda:0'),
#   tensor([[0.9130]], device='cuda:0')],
#  '2236156450': [tensor([[0.9218]], device='cuda:0'),
#   tensor([[0.9744]], device='cuda:0')],
#  '1990824315': [tensor([[0.9950]], device='cuda:0'),
#   tensor([[1.0000]], device='cuda:0')],
#  '2236142683': [tensor([[0.9761]], device='cuda:0'),
#   tensor([[0.8085]], device='cuda:0')],
#  '1998482052': [tensor([[0.9981]], device='cuda:0'),
#   tensor([[0.9701]], device='cuda:0')],
#  '1998413329': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9501]], device='cuda:0')]}

# %%
input_dir = "/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/TROCR_Training/goodfiles/"
output_dir = "data/Doc_Classification/output/"

for file_name, avg_scores in score_avg_dict.items():
#     print(input_dir+file_name+".jpg", scores)
#     print(file_name, avg_scores)
    
    source_file = input_dir+file_name+".jpg"
    
    # Copy the file using shutil.copy2 to the corresponding directory
    # based on the average prediction score
    if(avg_scores[0] >= avg_scores[1]):
        # print("handwritten")
        shutil.copy2(source_file, os.path.join(output_dir, "handwritten"))
        
    # add some bias here
    if(avg_scores[0] < avg_scores[1]):
        # print("typed")
        shutil.copy2(source_file, os.path.join(output_dir, "typed"))

# %%
! ls data/Doc_Classification/output/handwritten/ | wc -l
! ls data/Doc_Classification/output/typed/ | wc -l
# Out:
# 167
# 82

# %%
# ! rm -rf data/Doc_Classification/output/handwritten/*
# ! rm -rf data/Doc_Classification/output/typed/*
