# %%
import os
import shutil
from collections import defaultdict
from tqdm import tqdm
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torchvision.transforms import transforms
from torchvision.transforms.functional import pad

from utils.utils import *
from craft_text_detector import Craft

# %%
# --in-dir
# --out-dir
# --model-path

# %%
workdir = "/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/TROCR_Training/goodfiles/"
output_dir_craft = "data/Doc_Classification/input"

# initialize the CRAFT model
craft = Craft(output_dir = output_dir_craft, 
              export_extra = False, 
              text_threshold = .7, 
              link_threshold = .4, 
              crop_type="poly", 
              low_text = .3, 
              cuda = True)

# CRAFT on images to get bounding boxes
images = []
corrupted_images = []
no_segmentations = []
boxes = {}
count= 0
img_name = []
box = []
file_types = (".jpg", ".jpeg",".png")
    
for filename in tqdm(sorted(os.listdir(workdir))):
    if filename.endswith(file_types):
        image = workdir+filename
        try:
            img = Image.open(image) 
            img.verify() # Check that the image is valid
            bounding_areas = craft.detect_text(image)
            if len(bounding_areas['boxes']): #check that a segmentation was found
                images.append(image)
                boxes[image] = bounding_areas['boxes']
                
            else:
                no_segmentations.append(image)
        except (IOError, SyntaxError) as e:
            corrupted_images.append(image)

# %%
preprocess = transforms.Compose([
    transforms.Resize([100, ]),
    transforms.Lambda(
        lambda img: pad(img, padding=(0, 0, max(0, 200 - img.width), max(0, 100 - img.height)), 
                                              fill=(255, 255, 255))),
    transforms.CenterCrop((100, 200)),
    PartialErosion(iterations=2),
    transforms.ToTensor(),
    transforms.Grayscale(num_output_channels=3),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %%
# Move the model to the device (CPU or GPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
# vgg_from_scratch_w_erosion_v2.pth

best_model = models.densenet121(weights="DenseNet121_Weights.IMAGENET1K_V1")
# Modify the model for binary classification
num_ftrs = best_model.classifier.in_features
best_model.classifier = nn.Linear(num_ftrs, 1)

# best_model = VGG16Binary(input_shape=(3, 100, 200), num_classes=1)  # Create an instance of the model

best_model.load_state_dict(torch.load('model/densenet_10_5_layers_unlocked.pth'))
best_model = best_model.to(device)

# %%
score_sum_dict = defaultdict(lambda: [0, 0]) # file_name: (hw_confidence, typed_confidence)
score_len_dict = defaultdict(lambda: [0, 0]) # file_name: (hw_count, typed_count)

# %%
craft_output_dir = "/projectnb/sparkgrp/kabilanm/goodfilescraft/"

for dir_ in os.listdir(craft_output_dir):
    for file in os.listdir(os.path.join(craft_output_dir, dir_)):
#         print(dir_+"/"+file)
        
        key = dir_.split("_")[0]
        
        img = Image.open(craft_output_dir+dir_+"/"+file)
        input_tensor = preprocess(img)

        # Expand dimensions
        input_tensor = torch.unsqueeze(input_tensor, 0)
        input_tensor = input_tensor.to('cuda')

        best_model.eval()
        with torch.no_grad():
            outputs = best_model(input_tensor)
            
            pred_confidence = torch.sigmoid(outputs)
            predicted = torch.round(pred_confidence)
            
            if(predicted == 0):
                score_sum_dict[key][0] += 1-pred_confidence
                score_len_dict[key][0] += 1
            if(predicted == 1):
                score_sum_dict[key][1] += pred_confidence
                score_len_dict[key][1] += 1

# %%
score_sum_dict = dict(score_sum_dict)
score_len_dict = dict(score_len_dict)

# %%
score_avg_dict = defaultdict(lambda: [0, 0])

# %%
hw_score, typed_score = 0, 0

for sum_, len_ in zip(score_sum_dict.items(), score_len_dict.items()):
    if(len_[1][0] == 0):
        hw_score = 0
    elif(len_[1][1] == 0):
        typed_score = 0
    else:
        hw_score = sum_[1][0]/len_[1][0]
        typed_score = sum_[1][1]/len_[1][1]
    score_avg_dict[sum_[0]] = [hw_score, typed_score]

# %%
score_avg_dict = dict(score_avg_dict)
score_avg_dict
# Out:
# {'2452230713': [tensor([[0.9985]], device='cuda:0'),
#   tensor([[0.9889]], device='cuda:0')],
#  '2900445104': [tensor([[0.9697]], device='cuda:0'),
#   tensor([[0.9347]], device='cuda:0')],
#  '2575039168': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9626]], device='cuda:0')],
#  '2236018163': [tensor([[0.9718]], device='cuda:0'),
#   tensor([[0.9971]], device='cuda:0')],
#  '2235956175': [tensor([[0.9574]], device='cuda:0'),
#   tensor([[0.9632]], device='cuda:0')],
#  '2426921679': [0, tensor([[0.9632]], device='cuda:0')],
#  '2859042459': [tensor([[0.9911]], device='cuda:0'),
#   tensor([[0.9875]], device='cuda:0')],
#  '1563240212': [tensor([[0.9300]], device='cuda:0'),
#   tensor([[0.9940]], device='cuda:0')],
#  '3467354375': [tensor([[0.9843]], device='cuda:0'),
#   tensor([[0.8970]], device='cuda:0')],
#  '1998387136': [tensor([[0.9995]], device='cuda:0'),
#   tensor([[0.9951]], device='cuda:0')],
#  '2265485412': [tensor([[0.9456]], device='cuda:0'),
#   tensor([[0.9668]], device='cuda:0')],
#  '1998758107': [tensor([[0.9223]], device='cuda:0'),
#   tensor([[0.9447]], device='cuda:0')],
#  '2848506530': [tensor([[0.9088]], device='cuda:0'),
#   tensor([[0.9737]], device='cuda:0')],
#  '3356803607': [tensor([[0.9012]], device='cuda:0'),
#   tensor([[0.9534]], device='cuda:0')],
#  '3341248414': [tensor([[0.8095]], device='cuda:0'),
#   tensor([[0.9860]], device='cuda:0')],
#  '2595747531': [tensor([[0.9759]], device='cuda:0'),
#   tensor([[0.9610]], device='cuda:0')],
#  '1322253698': [tensor([[0.9951]], device='cuda:0'),
#   tensor([[0.9570]], device='cuda:0')],
#  '1802596511': [tensor([[0.9859]], device='cuda:0'),
#   tensor([[0.9565]], device='cuda:0')],
#  '2575053354': [0, tensor([[0.9565]], device='cuda:0')],
#  '1998387245': [tensor([[0.9993]], device='cuda:0'),
#   tensor([[0.9638]], device='cuda:0')],
#  '3356834058': [tensor([[0.9994]], device='cuda:0'),
#   tensor([[0.9515]], device='cuda:0')],
#  '1320460457': [tensor([[0.9754]], device='cuda:0'),
#   tensor([[0.9881]], device='cuda:0')],
#  '3341239321': [tensor([[0.8933]], device='cuda:0'),
#   tensor([[0.9594]], device='cuda:0')],
#  '2012884607': [tensor([[0.9940]], device='cuda:0'),
#   tensor([[0.9536]], device='cuda:0')],
#  '2236950433': [0, tensor([[0.9536]], device='cuda:0')],
#  '2571504032': [tensor([[0.9582]], device='cuda:0'),
#   tensor([[0.9564]], device='cuda:0')],
#  '1928276301': [tensor([[0.9661]], device='cuda:0'),
#   tensor([[0.9719]], device='cuda:0')],
#  '2284154890': [tensor([[0.8277]], device='cuda:0'),
#   tensor([[0.9801]], device='cuda:0')],
#  '2452246731': [tensor([[0.9765]], device='cuda:0'),
#   tensor([[0.9216]], device='cuda:0')],
#  '1456276626': [tensor([[0.9949]], device='cuda:0'),
#   tensor([[0.9896]], device='cuda:0')],
#  '2848503382': [tensor([[0.8786]], device='cuda:0'),
#   tensor([[0.9639]], device='cuda:0')],
#  '2452262576': [tensor([[0.8142]], device='cuda:0'),
#   tensor([[0.9240]], device='cuda:0')],
#  '2625873744': [tensor([[0.9143]], device='cuda:0'),
#   tensor([[0.9519]], device='cuda:0')],
#  '2643351883': [tensor([[0.9199]], device='cuda:0'),
#   tensor([[0.9047]], device='cuda:0')],
#  '1927799942': [tensor([[0.8325]], device='cuda:0'),
#   tensor([[0.9751]], device='cuda:0')],
#  '1456008930': [tensor([[0.8695]], device='cuda:0'),
#   tensor([[0.9923]], device='cuda:0')],
#  '2425435971': [tensor([[0.5204]], device='cuda:0'),
#   tensor([[0.9969]], device='cuda:0')],
#  '1802552799': [tensor([[0.9362]], device='cuda:0'),
#   tensor([[0.9812]], device='cuda:0')],
#  '1999283271': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9888]], device='cuda:0')],
#  '1928034398': [tensor([[0.6975]], device='cuda:0'),
#   tensor([[0.9838]], device='cuda:0')],
#  '2900455868': [tensor([[0.8575]], device='cuda:0'),
#   tensor([[0.9449]], device='cuda:0')],
#  '2625852862': [tensor([[0.8500]], device='cuda:0'),
#   tensor([[0.9773]], device='cuda:0')],
#  '2900461439': [tensor([[0.7931]], device='cuda:0'),
#   tensor([[0.9515]], device='cuda:0')],
#  '2284326054': [tensor([[0.7960]], device='cuda:0'),
#   tensor([[0.9491]], device='cuda:0')],
#  '2608680770': [tensor([[0.9809]], device='cuda:0'),
#   tensor([[0.9553]], device='cuda:0')],
#  '2859305213': [tensor([[0.9933]], device='cuda:0'),
#   tensor([[0.9982]], device='cuda:0')],
#  '2452293722': [tensor([[0.9678]], device='cuda:0'),
#   tensor([[0.9594]], device='cuda:0')],
#  '1998994775': [tensor([[0.9346]], device='cuda:0'),
#   tensor([[0.9009]], device='cuda:0')],
#  '2426917844': [tensor([[0.8723]], device='cuda:0'),
#   tensor([[0.9438]], device='cuda:0')],
#  '1999028044': [tensor([[0.9152]], device='cuda:0'),
#   tensor([[0.9425]], device='cuda:0')],
#  '1426171668': [tensor([[0.9588]], device='cuda:0'),
#   tensor([[0.9190]], device='cuda:0')],
#  '1702851818': [tensor([[0.9953]], device='cuda:0'),
#   tensor([[0.9758]], device='cuda:0')],
#  '2595756978': [tensor([[0.9407]], device='cuda:0'),
#   tensor([[0.9906]], device='cuda:0')],
#  '1318797445': [tensor([[0.9668]], device='cuda:0'),
#   tensor([[0.9027]], device='cuda:0')],
#  '1998370401': [tensor([[0.9606]], device='cuda:0'),
#   tensor([[0.9882]], device='cuda:0')],
#  '1998333126': [tensor([[0.8675]], device='cuda:0'),
#   tensor([[0.9528]], device='cuda:0')],
#  '2236116492': [tensor([[0.9978]], device='cuda:0'),
#   tensor([[0.9573]], device='cuda:0')],
#  '1930277693': [tensor([[0.6926]], device='cuda:0'),
#   tensor([[0.9838]], device='cuda:0')],
#  '3111515383': [tensor([[0.7802]], device='cuda:0'),
#   tensor([[0.9960]], device='cuda:0')],
#  '2512789170': [tensor([[0.7384]], device='cuda:0'),
#   tensor([[0.9736]], device='cuda:0')],
#  '2284285249': [tensor([[0.9577]], device='cuda:0'),
#   tensor([[0.9928]], device='cuda:0')],
#  '2265509546': [tensor([[0.9707]], device='cuda:0'),
#   tensor([[0.9611]], device='cuda:0')],
#  '1426052966': [tensor([[0.9169]], device='cuda:0'),
#   tensor([[0.9892]], device='cuda:0')],
#  '1999130856': [tensor([[0.9997]], device='cuda:0'),
#   tensor([[0.9921]], device='cuda:0')],
#  '1998611243': [tensor([[0.8922]], device='cuda:0'),
#   tensor([[0.9362]], device='cuda:0')],
#  '2425414867': [tensor([[0.9944]], device='cuda:0'),
#   tensor([[0.8540]], device='cuda:0')],
#  '1998969928': [tensor([[0.9746]], device='cuda:0'),
#   tensor([[0.9617]], device='cuda:0')],
#  '1998540182': [tensor([[0.9659]], device='cuda:0'),
#   tensor([[0.9907]], device='cuda:0')],
#  '2565452643': [tensor([[0.9251]], device='cuda:0'),
#   tensor([[0.9560]], device='cuda:0')],
#  '2573054178': [tensor([[0.8511]], device='cuda:0'),
#   tensor([[0.9588]], device='cuda:0')],
#  '1998836464': [tensor([[0.8468]], device='cuda:0'),
#   tensor([[0.9691]], device='cuda:0')],
#  '2397800089': [tensor([[0.9887]], device='cuda:0'),
#   tensor([[0.9716]], device='cuda:0')],
#  '2859014941': [tensor([[0.8534]], device='cuda:0'),
#   tensor([[0.9396]], device='cuda:0')],
#  '1999047345': [tensor([[0.9935]], device='cuda:0'),
#   tensor([[0.9801]], device='cuda:0')],
#  '1319864119': [tensor([[0.9814]], device='cuda:0'),
#   tensor([[0.9418]], device='cuda:0')],
#  '1676047656': [tensor([[0.9079]], device='cuda:0'),
#   tensor([[0.9598]], device='cuda:0')],
#  '1317726996': [tensor([[0.9031]], device='cuda:0'),
#   tensor([[0.9939]], device='cuda:0')],
#  '1455174725': [tensor([[0.9246]], device='cuda:0'),
#   tensor([[0.8822]], device='cuda:0')],
#  '3459889344': [tensor([[0.9714]], device='cuda:0'),
#   tensor([[0.9951]], device='cuda:0')],
#  '2549483800': [tensor([[0.8898]], device='cuda:0'),
#   tensor([[0.9782]], device='cuda:0')],
#  '1999314245': [tensor([[0.8725]], device='cuda:0'),
#   tensor([[0.9616]], device='cuda:0')],
#  '1998543749': [tensor([[0.9266]], device='cuda:0'),
#   tensor([[0.9960]], device='cuda:0')],
#  '1928246346': [tensor([[0.9470]], device='cuda:0'),
#   tensor([[0.9726]], device='cuda:0')],
#  '1318373170': [tensor([[0.9698]], device='cuda:0'),
#   tensor([[0.9349]], device='cuda:0')],
#  '1929084979': [tensor([[0.8000]], device='cuda:0'),
#   tensor([[0.9612]], device='cuda:0')],
#  '3005768358': [tensor([[0.9303]], device='cuda:0'),
#   tensor([[0.9783]], device='cuda:0')],
#  '1322958063': [tensor([[0.8781]], device='cuda:0'),
#   tensor([[0.9511]], device='cuda:0')],
#  '2235995189': [tensor([[0.8333]], device='cuda:0'),
#   tensor([[0.9385]], device='cuda:0')],
#  '1318526260': [tensor([[0.9276]], device='cuda:0'),
#   tensor([[0.9709]], device='cuda:0')],
#  '1998308840': [tensor([[0.9984]], device='cuda:0'),
#   tensor([[0.9989]], device='cuda:0')],
#  '2265588715': [tensor([[0.9405]], device='cuda:0'),
#   tensor([[0.9716]], device='cuda:0')],
#  '2012879889': [tensor([[0.8299]], device='cuda:0'),
#   tensor([[0.9425]], device='cuda:0')],
#  '2446828060': [tensor([[0.9396]], device='cuda:0'),
#   tensor([[0.9785]], device='cuda:0')],
#  '1317746297': [tensor([[0.8061]], device='cuda:0'),
#   tensor([[0.9944]], device='cuda:0')],
#  '1319210580': [tensor([[0.8101]], device='cuda:0'),
#   tensor([[0.9372]], device='cuda:0')],
#  '1998818359': [tensor([[0.9228]], device='cuda:0'),
#   tensor([[0.9054]], device='cuda:0')],
#  '2284193310': [tensor([[0.9899]], device='cuda:0'),
#   tensor([[0.9227]], device='cuda:0')],
#  '1998843424': [tensor([[0.9932]], device='cuda:0'),
#   tensor([[0.9331]], device='cuda:0')],
#  '2235813242': [tensor([[0.9854]], device='cuda:0'),
#   tensor([[0.9630]], device='cuda:0')],
#  '1320398138': [tensor([[0.9307]], device='cuda:0'),
#   tensor([[0.9178]], device='cuda:0')],
#  '1931124118': [tensor([[0.9595]], device='cuda:0'),
#   tensor([[0.9770]], device='cuda:0')],
#  '3005750161': [tensor([[0.8217]], device='cuda:0'),
#   tensor([[0.9171]], device='cuda:0')],
#  '2900436116': [tensor([[0.9367]], device='cuda:0'),
#   tensor([[0.9100]], device='cuda:0')],
#  '1317278320': [tensor([[0.9064]], device='cuda:0'),
#   tensor([[0.9962]], device='cuda:0')],
#  '1318182025': [tensor([[0.8877]], device='cuda:0'),
#   tensor([[0.9625]], device='cuda:0')],
#  '2236176339': [tensor([[0.9024]], device='cuda:0'),
#   tensor([[0.9931]], device='cuda:0')],
#  '2284359495': [tensor([[0.8788]], device='cuda:0'),
#   tensor([[0.9531]], device='cuda:0')],
#  '2848499425': [tensor([[0.9142]], device='cuda:0'),
#   tensor([[0.9374]], device='cuda:0')],
#  '1929709919': [tensor([[0.9037]], device='cuda:0'),
#   tensor([[0.9623]], device='cuda:0')],
#  '1998550976': [tensor([[0.9151]], device='cuda:0'),
#   tensor([[0.9743]], device='cuda:0')],
#  '1318027385': [tensor([[0.9588]], device='cuda:0'),
#   tensor([[0.9872]], device='cuda:0')],
#  '1212567865': [tensor([[0.9394]], device='cuda:0'),
#   tensor([[0.9362]], device='cuda:0')],
#  '3005670412': [tensor([[0.8037]], device='cuda:0'),
#   tensor([[0.9650]], device='cuda:0')],
#  '2426902656': [tensor([[0.8474]], device='cuda:0'),
#   tensor([[0.9810]], device='cuda:0')],
#  '1998590947': [tensor([[0.9568]], device='cuda:0'),
#   tensor([[0.9916]], device='cuda:0')],
#  '1998808952': [tensor([[0.8150]], device='cuda:0'),
#   tensor([[0.9548]], device='cuda:0')],
#  '2265566552': [tensor([[1.0000]], device='cuda:0'),
#   tensor([[0.9912]], device='cuda:0')],
#  '3092956655': [tensor([[0.9584]], device='cuda:0'),
#   tensor([[0.9865]], device='cuda:0')],
#  '1999253468': [tensor([[0.8231]], device='cuda:0'),
#   tensor([[0.9648]], device='cuda:0')],
#  '2575086103': [tensor([[0.9983]], device='cuda:0'),
#   tensor([[0.9831]], device='cuda:0')],
#  '1998497875': [tensor([[0.9552]], device='cuda:0'),
#   tensor([[0.9550]], device='cuda:0')],
#  '1999032409': [tensor([[0.9883]], device='cuda:0'),
#   tensor([[0.9789]], device='cuda:0')],
#  '2284189808': [tensor([[0.9697]], device='cuda:0'),
#   tensor([[0.9811]], device='cuda:0')],
#  '2625851024': [tensor([[0.7790]], device='cuda:0'),
#   tensor([[0.9857]], device='cuda:0')],
#  '3357284466': [tensor([[0.9915]], device='cuda:0'),
#   tensor([[0.9867]], device='cuda:0')],
#  '1998465329': [tensor([[0.9894]], device='cuda:0'),
#   tensor([[0.9991]], device='cuda:0')],
#  '437160969': [tensor([[0.9414]], device='cuda:0'),
#   tensor([[0.9334]], device='cuda:0')],
#  '2234232983': [tensor([[0.8798]], device='cuda:0'),
#   tensor([[0.8997]], device='cuda:0')],
#  '1702827727': [tensor([[0.9440]], device='cuda:0'),
#   tensor([[0.9557]], device='cuda:0')],
#  '2284153322': [tensor([[0.8385]], device='cuda:0'),
#   tensor([[0.8985]], device='cuda:0')],
#  '2549491705': [tensor([[0.9024]], device='cuda:0'),
#   tensor([[0.9380]], device='cuda:0')],
#  '1990825865': [tensor([[0.9562]], device='cuda:0'),
#   tensor([[0.9584]], device='cuda:0')],
#  '1999330570': [tensor([[0.8765]], device='cuda:0'),
#   tensor([[0.9839]], device='cuda:0')],
#  '2397779786': [tensor([[0.9452]], device='cuda:0'),
#   tensor([[0.9163]], device='cuda:0')],
#  '2236147388': [tensor([[0.7848]], device='cuda:0'),
#   tensor([[0.9719]], device='cuda:0')],
#  '2284150251': [tensor([[0.9102]], device='cuda:0'),
#   tensor([[0.9919]], device='cuda:0')],
#  '1843567618': [tensor([[0.8130]], device='cuda:0'),
#   tensor([[0.9230]], device='cuda:0')],
#  '1998358368': [tensor([[0.9093]], device='cuda:0'),
#   tensor([[0.9255]], device='cuda:0')],
#  '2608673843': [tensor([[0.9617]], device='cuda:0'),
#   tensor([[0.9832]], device='cuda:0')],
#  '2425404585': [tensor([[0.9590]], device='cuda:0'),
#   tensor([[0.9958]], device='cuda:0')],
#  '1456376042': [tensor([[0.9138]], device='cuda:0'),
#   tensor([[0.9970]], device='cuda:0')],
#  '2592238071': [tensor([[0.8932]], device='cuda:0'),
#   tensor([[0.9427]], device='cuda:0')],
#  '1929881359': [tensor([[0.9310]], device='cuda:0'),
#   tensor([[0.9976]], device='cuda:0')],
#  '1929883118': [0, tensor([[0.9976]], device='cuda:0')],
#  '1998968996': [tensor([[0.9792]], device='cuda:0'),
#   tensor([[0.9793]], device='cuda:0')],
#  '2848440467': [tensor([[0.9007]], device='cuda:0'),
#   tensor([[0.9922]], device='cuda:0')],
#  '1318293083': [tensor([[0.9715]], device='cuda:0'),
#   tensor([[0.9564]], device='cuda:0')],
#  '2565407235': [tensor([[0.9133]], device='cuda:0'),
#   tensor([[0.9726]], device='cuda:0')],
#  '1318334082': [tensor([[0.8696]], device='cuda:0'),
#   tensor([[0.9480]], device='cuda:0')],
#  '1999143240': [tensor([[0.9966]], device='cuda:0'),
#   tensor([[0.9939]], device='cuda:0')],
#  '3043554903': [tensor([[0.9260]], device='cuda:0'),
#   tensor([[0.9723]], device='cuda:0')],
#  '2446828826': [tensor([[0.8200]], device='cuda:0'),
#   tensor([[0.9357]], device='cuda:0')],
#  '1998467065': [tensor([[0.9047]], device='cuda:0'),
#   tensor([[0.9248]], device='cuda:0')],
#  '2236597761': [tensor([[0.9889]], device='cuda:0'),
#   tensor([[0.9632]], device='cuda:0')],
#  '3385632342': [tensor([[0.9614]], device='cuda:0'),
#   tensor([[0.9792]], device='cuda:0')],
#  '1990809725': [tensor([[0.9529]], device='cuda:0'),
#   tensor([[0.9667]], device='cuda:0')],
#  '1675940934': [tensor([[0.9642]], device='cuda:0'),
#   tensor([[0.9418]], device='cuda:0')],
#  '2235847388': [tensor([[0.7660]], device='cuda:0'),
#   tensor([[0.9751]], device='cuda:0')],
#  '3734813368': [tensor([[0.8629]], device='cuda:0'),
#   tensor([[0.9607]], device='cuda:0')],
#  '2235866543': [tensor([[0.9711]], device='cuda:0'),
#   tensor([[0.9792]], device='cuda:0')],
#  '3392122454': [tensor([[0.7876]], device='cuda:0'),
#   tensor([[0.9879]], device='cuda:0')],
#  '1321992876': [tensor([[0.9613]], device='cuda:0'),
#   tensor([[0.9927]], device='cuda:0')],
#  '2549496787': [tensor([[0.9044]], device='cuda:0'),
#   tensor([[0.9556]], device='cuda:0')],
#  '1999217275': [tensor([[0.9798]], device='cuda:0'),
#   tensor([[0.9720]], device='cuda:0')],
#  '1455960532': [tensor([[0.9022]], device='cuda:0'),
#   tensor([[0.9990]], device='cuda:0')],
#  '2235750047': [tensor([[0.8096]], device='cuda:0'),
#   tensor([[0.9093]], device='cuda:0')],
#  '2592277723': [tensor([[0.9481]], device='cuda:0'),
#   tensor([[0.9675]], device='cuda:0')],
#  '1321746477': [tensor([[0.9797]], device='cuda:0'),
#   tensor([[0.9117]], device='cuda:0')],
#  '1998956483': [tensor([[0.8328]], device='cuda:0'),
#   tensor([[0.9710]], device='cuda:0')],
#  '2446819762': [tensor([[0.9369]], device='cuda:0'),
#   tensor([[0.9779]], device='cuda:0')],
#  '2859205685': [tensor([[0.9582]], device='cuda:0'),
#   tensor([[0.9796]], device='cuda:0')],
#  '2549492260': [tensor([[0.9906]], device='cuda:0'),
#   tensor([[0.9791]], device='cuda:0')],
#  '1998882868': [tensor([[0.9668]], device='cuda:0'),
#   tensor([[0.9968]], device='cuda:0')],
#  '1999401722': [tensor([[0.9110]], device='cuda:0'),
#   tensor([[0.9979]], device='cuda:0')],
#  '2512759946': [tensor([[0.7795]], device='cuda:0'),
#   tensor([[0.9453]], device='cuda:0')],
#  '1852124166': [tensor([[0.8666]], device='cuda:0'),
#   tensor([[0.9608]], device='cuda:0')],
#  '2549603947': [tensor([[0.9026]], device='cuda:0'),
#   tensor([[0.9108]], device='cuda:0')],
#  '3092906623': [tensor([[0.8917]], device='cuda:0'),
#   tensor([[0.9810]], device='cuda:0')],
#  '2625898343': [tensor([[0.9892]], device='cuda:0'),
#   tensor([[0.9076]], device='cuda:0')],
#  '1998322454': [tensor([[0.8390]], device='cuda:0'),
#   tensor([[0.9978]], device='cuda:0')],
#  '2235965636': [tensor([[0.9173]], device='cuda:0'),
#   tensor([[0.9572]], device='cuda:0')],
#  '2625876902': [tensor([[0.8692]], device='cuda:0'),
#   tensor([[0.9515]], device='cuda:0')],
#  '1318345053': [tensor([[0.8761]], device='cuda:0'),
#   tensor([[0.9622]], device='cuda:0')],
#  '3005755518': [tensor([[0.9211]], device='cuda:0'),
#   tensor([[0.9596]], device='cuda:0')],
#  '2425445076': [tensor([[0.9881]], device='cuda:0'),
#   tensor([[0.9519]], device='cuda:0')],
#  '1998394637': [tensor([[0.9794]], device='cuda:0'),
#   tensor([[0.9816]], device='cuda:0')],
#  '1999262308': [tensor([[0.9304]], device='cuda:0'),
#   tensor([[0.9246]], device='cuda:0')],
#  '3005774322': [tensor([[0.9745]], device='cuda:0'),
#   tensor([[0.9307]], device='cuda:0')],
#  '2236031445': [tensor([[0.8838]], device='cuda:0'),
#   tensor([[0.9441]], device='cuda:0')],
#  '2643353998': [tensor([[0.9333]], device='cuda:0'),
#   tensor([[0.9210]], device='cuda:0')],
#  '1317840733': [tensor([[0.9156]], device='cuda:0'),
#   tensor([[0.9788]], device='cuda:0')],
#  '1456250583': [tensor([[0.9465]], device='cuda:0'),
#   tensor([[0.9857]], device='cuda:0')],
#  '1319326174': [tensor([[0.9927]], device='cuda:0'),
#   tensor([[0.9008]], device='cuda:0')],
#  '1999105588': [tensor([[0.9619]], device='cuda:0'),
#   tensor([[0.9854]], device='cuda:0')],
#  '1998980522': [tensor([[0.9999]], device='cuda:0'),
#   tensor([[0.9546]], device='cuda:0')],
#  '1999167579': [tensor([[0.9906]], device='cuda:0'),
#   tensor([[0.9736]], device='cuda:0')],
#  '2452236904': [tensor([[0.8528]], device='cuda:0'),
#   tensor([[0.9559]], device='cuda:0')],
#  '2512820352': [tensor([[0.9861]], device='cuda:0'),
#   tensor([[0.9500]], device='cuda:0')],
#  '1999413720': [tensor([[0.9536]], device='cuda:0'),
#   tensor([[0.9573]], device='cuda:0')],
#  '2625904355': [tensor([[0.9081]], device='cuda:0'),
#   tensor([[0.9951]], device='cuda:0')],
#  '2512801142': [tensor([[0.8786]], device='cuda:0'),
#   tensor([[0.9379]], device='cuda:0')],
#  '1998543588': [tensor([[0.9679]], device='cuda:0'),
#   tensor([[0.9964]], device='cuda:0')],
#  '2235755905': [tensor([[0.9669]], device='cuda:0'),
#   tensor([[0.9489]], device='cuda:0')],
#  '1998686142': [tensor([[0.9633]], device='cuda:0'),
#   tensor([[0.9959]], device='cuda:0')],
#  '1320488541': [tensor([[0.6915]], device='cuda:0'),
#   tensor([[0.9999]], device='cuda:0')],
#  '2425437928': [tensor([[0.9755]], device='cuda:0'),
#   tensor([[0.9432]], device='cuda:0')],
#  '1998729261': [tensor([[0.8780]], device='cuda:0'),
#   tensor([[0.9754]], device='cuda:0')],
#  '2397721138': [tensor([[0.8173]], device='cuda:0'),
#   tensor([[0.9597]], device='cuda:0')],
#  '1322099762': [tensor([[0.9349]], device='cuda:0'),
#   tensor([[0.9726]], device='cuda:0')],
#  '2512761763': [tensor([[0.7926]], device='cuda:0'),
#   tensor([[0.9417]], device='cuda:0')],
#  '1318393575': [tensor([[0.9555]], device='cuda:0'),
#   tensor([[0.8939]], device='cuda:0')],
#  '1999110359': [tensor([[0.9979]], device='cuda:0'),
#   tensor([[0.9408]], device='cuda:0')],
#  '1999154508': [tensor([[0.8338]], device='cuda:0'),
#   tensor([[0.9776]], device='cuda:0')],
#  '1318212360': [tensor([[0.7868]], device='cuda:0'),
#   tensor([[0.9685]], device='cuda:0')],
#  '1998646322': [tensor([[0.9967]], device='cuda:0'),
#   tensor([[0.9633]], device='cuda:0')],
#  '2512855384': [tensor([[0.8904]], device='cuda:0'),
#   tensor([[0.9676]], device='cuda:0')],
#  '2858981761': [tensor([[0.8416]], device='cuda:0'),
#   tensor([[0.9539]], device='cuda:0')],
#  '2284257102': [tensor([[0.9012]], device='cuda:0'),
#   tensor([[0.9704]], device='cuda:0')],
#  '2236024256': [tensor([[0.8412]], device='cuda:0'),
#   tensor([[0.9384]], device='cuda:0')],
#  '2512764119': [tensor([[0.7918]], device='cuda:0'),
#   tensor([[0.9346]], device='cuda:0')],
#  '1998481102': [tensor([[0.9235]], device='cuda:0'),
#   tensor([[0.9642]], device='cuda:0')],
#  '2236057326': [tensor([[0.8883]], device='cuda:0'),
#   tensor([[0.9621]], device='cuda:0')],
#  '1999056693': [tensor([[0.9801]], device='cuda:0'),
#   tensor([[0.9456]], device='cuda:0')],
#  '1852143901': [tensor([[0.8908]], device='cuda:0'),
#   tensor([[0.8801]], device='cuda:0')],
#  '1320104750': [tensor([[0.8733]], device='cuda:0'),
#   tensor([[0.9566]], device='cuda:0')],
#  '1426166249': [tensor([[0.9400]], device='cuda:0'),
#   tensor([[0.9148]], device='cuda:0')],
#  '1999410499': [tensor([[0.8708]], device='cuda:0'),
#   tensor([[0.9669]], device='cuda:0')],
#  '1322630109': [tensor([[0.8968]], device='cuda:0'),
#   tensor([[0.9826]], device='cuda:0')],
#  '2235846679': [tensor([[0.9497]], device='cuda:0'),
#   tensor([[0.9244]], device='cuda:0')],
#  '3005727173': [tensor([[0.8913]], device='cuda:0'),
#   tensor([[0.9775]], device='cuda:0')],
#  '1930449245': [tensor([[0.8352]], device='cuda:0'),
#   tensor([[0.9430]], device='cuda:0')],
#  '3341257544': [tensor([[0.9713]], device='cuda:0'),
#   tensor([[0.9977]], device='cuda:0')],
#  '1998565761': [tensor([[0.8628]], device='cuda:0'),
#   tensor([[0.9793]], device='cuda:0')],
#  '1999317509': [tensor([[0.9275]], device='cuda:0'),
#   tensor([[0.9796]], device='cuda:0')],
#  '2452332496': [tensor([[0.9007]], device='cuda:0'),
#   tensor([[0.9823]], device='cuda:0')],
#  '1928479020': [tensor([[0.9999]], device='cuda:0'),
#   tensor([[0.9900]], device='cuda:0')],
#  '2571435846': [tensor([[0.8088]], device='cuda:0'),
#   tensor([[0.9393]], device='cuda:0')],
#  '3703056529': [tensor([[0.9861]], device='cuda:0'),
#   tensor([[0.9955]], device='cuda:0')],
#  '2512804326': [tensor([[0.9527]], device='cuda:0'),
#   tensor([[0.9242]], device='cuda:0')],
#  '2397724211': [tensor([[0.9930]], device='cuda:0'),
#   tensor([[0.9739]], device='cuda:0')],
#  '1928370989': [tensor([[0.8585]], device='cuda:0'),
#   tensor([[0.9925]], device='cuda:0')],
#  '1563299852': [tensor([[0.8360]], device='cuda:0'),
#   tensor([[0.9076]], device='cuda:0')],
#  '3356836015': [tensor([[0.9862]], device='cuda:0'),
#   tensor([[0.9396]], device='cuda:0')],
#  '2426886454': [tensor([[0.9271]], device='cuda:0'),
#   tensor([[0.9130]], device='cuda:0')],
#  '2236156450': [tensor([[0.8484]], device='cuda:0'),
#   tensor([[0.9744]], device='cuda:0')],
#  '1990824315': [tensor([[0.9659]], device='cuda:0'),
#   tensor([[0.9538]], device='cuda:0')],
#  '2236142683': [tensor([[0.8062]], device='cuda:0'),
#   tensor([[0.8913]], device='cuda:0')],
#  '1998482052': [tensor([[0.9934]], device='cuda:0'),
#   tensor([[0.9787]], device='cuda:0')],
#  '1998413329': [tensor([[0.9166]], device='cuda:0'),
#   tensor([[0.9870]], device='cuda:0')]}

# %%
input_dir = "/projectnb/sparkgrp/ml-herbarium-grp/ml-herbarium-data/TROCR_Training/goodfiles/"
output_dir = "data/Doc_Classification/output/"

for file_name, avg_scores in score_avg_dict.items():
#     print(input_dir+file_name+".jpg", scores)
#     print(file_name, avg_scores)
    
    source_file = input_dir+file_name+".jpg"
    
    # Copy the file using shutil.copy2 to the corresponding directory
    # based on the average prediction score
    if(avg_scores[0] >= avg_scores[1]):
        # print("handwritten")
        shutil.copy2(source_file, os.path.join(output_dir, "handwritten"))
        
    # add some bias here
    if(avg_scores[0] < avg_scores[1]):
        # print("typed")
        shutil.copy2(source_file, os.path.join(output_dir, "typed"))
# Out:
# handwritten
# handwritten
# handwritten
# typed
# typed
# typed
# handwritten
# typed
# handwritten
# handwritten
# typed
# typed
# typed
# typed
# typed
# handwritten
# handwritten
# handwritten
# typed
# handwritten
# handwritten
# typed
# typed
# handwritten
# typed
# handwritten
# typed
# typed
# handwritten
# handwritten
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# handwritten
# handwritten
# typed
# typed
# handwritten
# handwritten
# typed
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# handwritten
# typed
# handwritten
# typed
# handwritten
# handwritten
# typed
# typed
# typed
# typed
# handwritten
# typed
# handwritten
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# handwritten
# handwritten
# handwritten
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# handwritten
# handwritten
# handwritten
# typed
# typed
# handwritten
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# handwritten
# handwritten
# typed
# handwritten
# typed
# typed
# handwritten
# typed
# handwritten
# handwritten
# typed
# handwritten
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# handwritten
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# handwritten
# typed
# handwritten
# typed
# typed
# handwritten
# typed
# typed
# typed
# typed
# typed
# typed
# handwritten
# typed
# typed
# handwritten
# handwritten
# typed
# typed
# handwritten
# handwritten
# typed
# handwritten
# typed
# handwritten
# typed

# %%
! ls data/Doc_Classification/output/handwritten/ | wc -l
! ls data/Doc_Classification/output/typed/ | wc -l
# Out:
# 79
# 170

# %%
! rm -rf data/Doc_Classification/output/handwritten/*
! rm -rf data/Doc_Classification/output/typed/*
